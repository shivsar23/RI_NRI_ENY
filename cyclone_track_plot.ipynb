# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
# Define the coordinates of the Bay of Bengal region
lon_min, lon_max = 70, 105
lat_min, lat_max = -4, 30

# Provided track data
track_data = [
    (10.4, 87.0), (10.9, 86.3), (10.9, 86.3), (11.1, 86.1),
    (11.4, 86.0), (11.5, 86.0), (12.0, 86.0), (12.5, 86.1),
    (13.2, 86.3), (13.4, 86.2), (14.0, 86.3), (14.9, 86.5),
    (15.6, 86.7), (16.5, 86.9), (17.4, 87.0), (18.4, 87.2),
    (19.1, 87.5), (20.6, 88.0), (21.9, 88.4), (23.3, 89.0),
    (24.2, 89.3), (25.0, 89.6), (25.4, 89.6),
]

# Extract latitude and longitude from the track_data
lats, lons = zip(*track_data)

# Create a new figure
fig = plt.figure(figsize=(10, 10))

# Create a Cartopy map with a PlateCarree projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Set the extent based on the track data
ax.set_extent([lon_min, lon_max, lat_min, lat_max])
# Add grey color to land
ax.add_feature(cfeature.LAND, facecolor='lightgrey')
#Add skyblue color to ocean
ax.add_feature(cfeature.OCEAN, color = 'lightblue')
# Add coastline and borders
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Plot the track data as a sky blue line
ax.plot(lons, lats, color='blue', transform=ccrs.PlateCarree())

# Add a dark point at the initial point of the track
ax.plot(lons[0], lats[0], 'ko', markersize=5, transform=ccrs.PlateCarree())

# Label latitude and longitude values on the axes
ax.set_xticks(range(lon_min, lon_max+1, 5), crs=ccrs.PlateCarree())
ax.set_yticks(range(lat_min, lat_max+1, 5), crs=ccrs.PlateCarree())
lon_formatter = LongitudeFormatter(zero_direction_label=True)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# Define the coordinates of the Bay of Bengal region
lon_min, lon_max = 70, 105
lat_min, lat_max = 0, 30


# Define track data for multiple cyclones
cyclone_tracks = [
[(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(18.0,92),(18.0,92),
 (18.0,92.0),(18.5,92.5),(18.5,92.5),(19.0,93),(19.0,93),(19.5,93.5),(19.8,93.5),(20.0,93.5),
 (20.5,94),(20.5,94),(21.0,94.5),(21.5,95),(22.0,95.5),],

[(12.0,96.0),(12.0,95.5),(12.0,95),(12.0,94.5),(12.25,94.25),(12.5,94.0),(13.0,93.5),(13.0,93.5),(13.0,93.0),(13.5,92.5),
 (13.5,92.5),(13.6,92.5),(14.0,92.0),(14.0,92.0),(14.5,91.5),(14.5,91.0),(15.0,90.5),(15.0,90.5),
 (15.5,90.0),(15.5,90.0),(15.5,89.5),(15.5,89.0),(16.0,88.5),(16.0,88.5),(16.2,88.3),(16.5,88.0),
 (16.8,87.7),(16.9,87.2),(17.0,87.0),(17.1,86.8),(17.5,86.5),(17.8,86.0),(18.1,85.7),(18.6,85.4),
 (18.7,85.2),(19.1,85.2),(19.5,84.8),(20.0,84.5),(20.5,84.5),(21.0,84.0),(21.5,84.0),(21.8,83.8),
 (22.5,83.8),(22.75,83.65),(23.0,83.5),(23.25,83.75),(23.5,84.0),(24.0,84.1),(24.5,84.2),],

[(10.0,84.0),(10.0,84.0),(10.1,84.0),(10.2,84.0),(10.3,84.0),(10.4,84.0),(10.45,84.05),(10.5,84.1),(10.5,84.1),(10.7,84.2),(10.8,84.3),
 (24.2, 89.3), (24.7, 89.5), (25.0, 89.6), (25.2,89.6), (25.4, 89.6),],

[(8.3, 89.5),(8.4,89.4), (8.5, 89.3),(8.5,89.15), (8.5, 89.0), (8.8, 88.9), (9.1, 88.7),(9.55,88.55), (10.0, 88.4),(10.4,88.3), (10.8, 88.2),(11,88.15), (11.2, 88.1),
 (11.4, 88.0), (11.6, 88.0), (11.8, 88.0), (12.2, 88.0), (12.5, 88.1), (12.7, 88.1), (12.9, 88.1), (13.2, 88.1),
 (13.6, 88.2), (14.0, 88.3), (14.3, 88.4), (14.6, 88.6), (14.8, 88.7), (15.1, 88.8), (15.2, 88.9), (15.4, 89.1),
 (15.7, 89.5), (16.0, 90.0), (16.4, 90.3), (16.9, 90.8), (17.4, 90.9), (17.9, 91.0), (18.3, 91.3), (18.7, 91.5),
 (19.3, 91.9), (19.9, 92.5), (20.5, 92.9), (21.1, 93.3), (21.8, 93.8), (22.7, 94.6), (23.5, 95.3), (23.9, 97.8),
 ],

    # Add more cyclone track data lists as needed
]

# Create a new figure
fig = plt.figure(figsize=(10, 10))

# Create a Cartopy map with a PlateCarree projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Set the extent based on the track data
ax.set_extent([lon_min, lon_max, lat_min, lat_max])

# Add grey color to land
ax.add_feature(cfeature.LAND, facecolor='lightgrey')

# Add skyblue color to ocean
ax.add_feature(cfeature.OCEAN, color='lightblue')

# Add coastline and borders
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Plot all cyclone tracks in blue
for track_data in cyclone_tracks:
    lats, lons = zip(*track_data)
    ax.plot(lons, lats, color='blue', transform=ccrs.PlateCarree())

    # Add dark point at the initial point of the track
    ax.plot(lons[0], lats[0], 'ko', markersize=5, transform=ccrs.PlateCarree())

# Label latitude and longitude values on the axes
ax.set_xticks(range(lon_min, lon_max + 1, 5), crs=ccrs.PlateCarree())
ax.set_yticks(range(lat_min, lat_max + 1, 5), crs=ccrs.PlateCarree())
lon_formatter = LongitudeFormatter(zero_direction_label=True)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# Define the coordinates of the Bay of Bengal region
lon_min, lon_max = 70, 105
lat_min, lat_max = 0, 30

# Define track data for multiple cyclones
cyclone_tracks = [
[(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(18.0,92),(18.0,92),
 (18.0,92.0),(18.5,92.5),(18.5,92.5),(19.0,93),(19.0,93),(19.5,93.5),(19.8,93.5),(20.0,93.5),
 (20.5,94),(20.5,94),(21.0,94.5),(21.5,95),(22.0,95.5),],

[(12.0,96.0),(12.0,95.5),(12.0,95),(12.0,94.5),(12.25,94.25),(12.5,94.0),(13.0,93.5),(13.0,93.5),(13.0,93.0),(13.5,92.5),
 (13.5,92.5),(13.6,92.5),(14.0,92.0),(14.0,92.0),(14.5,91.5),(14.5,91.0),(15.0,90.5),(15.0,90.5),
 (15.5,90.0),(15.5,90.0),(15.5,89.5),(15.5,89.0),(16.0,88.5),(16.0,88.5),(16.2,88.3),(16.5,88.0),
 (16.8,87.7),(16.9,87.2),(17.0,87.0),(17.1,86.8),(17.5,86.5),(17.8,86.0),(18.1,85.7),(18.6,85.4),
 (13.2, 86.3), (13.3, 86.2), (13.4, 86.2), (13.7, 86.2), (14.0, 86.3), (14.5, 86.4), (14.9, 86.5), (15.2, 86.6), 
 (15.6, 86.7), (16.0, 86.8), (16.5, 86.9), (17.0, 86.9), (17.4, 87.0), (18.1, 87.1), (18.4, 87.2), (18.7, 87.2), 
 (19.1, 87.5), (19.8, 87.7), (20.6, 88.0), (21.4, 88.1), (21.9, 88.4), (22.7, 88.6), (23.3, 89.0), (24.2, 89.0), 
 (24.2, 89.3), (24.7, 89.5), (25.0, 89.6), (25.2,89.6), (25.4, 89.6),],

[(8.3, 89.5),(8.4,89.4), (8.5, 89.3),(8.5,89.15), (8.5, 89.0), (8.8, 88.9), (9.1, 88.7),(9.55,88.55), (10.0, 88.4),(10.4,88.3), (10.8, 88.2),(11,88.15), (11.2, 88.1),
 (11.4, 88.0), (11.6, 88.0), (11.8, 88.0), (12.2, 88.0), (12.5, 88.1), (12.7, 88.1), (12.9, 88.1), (13.2, 88.1),
 (13.6, 88.2), (14.0, 88.3), (14.3, 88.4), (14.6, 88.6), (14.8, 88.7), (15.1, 88.8), (15.2, 88.9), (15.4, 89.1),
 (15.7, 89.5), (16.0, 90.0), (16.4, 90.3), (16.9, 90.8), (17.4, 90.9), (17.9, 91.0), (18.3, 91.3), (18.7, 91.5),
 (19.3, 91.9), (19.9, 92.5), (20.5, 92.9), (21.1, 93.3), (21.8, 93.8), (22.7, 94.6), (23.5, 95.3), (23.9, 97.8),
 ],

    # Add more cyclone track data lists as needed
]


# Define rapid intensification ranges for each cyclone
rapid_intensification_ranges = [
    (0,16),  # Rapid intensification range for cyclone 1
    (9,28),  # Rapid intensification range for cyclone 2
    (0,13),
    (33,42),
    (8,23),
    (23,38),
    (6,18),
    (16,29),
    (10,34),    # Add more tuples as needed for each cyclone
]
# Create a new figure
fig = plt.figure(figsize=(10, 10))

# Create a Cartopy map with a PlateCarree projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Set the extent based on the track data
ax.set_extent([lon_min, lon_max, lat_min, lat_max])

# Add grey color to land
ax.add_feature(cfeature.LAND, facecolor='lightgrey')

# Add skyblue color to ocean
ax.add_feature(cfeature.OCEAN, color='lightblue')

# Add coastline and borders
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')



# Plot all cyclone tracks
for track_data, rapid_range in zip(cyclone_tracks, rapid_intensification_ranges):
    lats, lons = zip(*track_data)
    start_idx, end_idx = rapid_range
    
    for i in range(len(lats) - 1):
        ax.plot(lons[0], lats[0], 'ko', markersize=5, transform=ccrs.PlateCarree())
        if start_idx <= i <= end_idx:
            color = 'red'
        else:
            color = 'green'
        
        ax.plot([lons[i], lons[i+1]], [lats[i], lats[i+1]], color=color, transform=ccrs.PlateCarree())



# Label latitude and longitude values on the axes
ax.set_xticks(range(lon_min, lon_max + 1, 5), crs=ccrs.PlateCarree())
ax.set_yticks(range(lat_min, lat_max + 1, 5), crs=ccrs.PlateCarree())
lon_formatter = LongitudeFormatter(zero_direction_label=True)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# Define the coordinates of the Bay of Bengal region
lon_min, lon_max = 70, 105
lat_min, lat_max = 0, 35

# Define track data for multiple cyclones
cyclone_tracks = [
{
        'name': 'Giri',
        'intensification_range': (0,16),  # Add the rapid intensification range for Cyclone here
        'track': [(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(17.5,91.5),(18.0,92),(18.0,92),
 (18.0,92.0),(18.5,92.5),(18.5,92.5),(19.0,93),(19.0,93),(19.5,93.5),(19.8,93.5),(20.0,93.5),
 (20.5,94),(20.5,94),(21.0,94.5),(21.5,95),(22.0,95.5),]  # Add the track data for Cyclone here
       
    },
{
        'name': 'Phailin',
        'intensification_range': (9,28),  # Add the rapid intensification range for Cyclone here
        'track': [(12.0,96.0),(12.0,95.5),(12.0,95),(12.0,94.5),(12.25,94.25),(12.5,94.0),(13.0,93.5),(13.0,93.5),(13.0,93.0),(13.5,92.5),
 (13.5,92.5),(13.6,92.5),(14.0,92.0),(14.0,92.0),(14.5,91.5),(14.5,91.0),(15.0,90.5),(15.0,90.5),
 (15.5,90.0),(15.5,90.0),(15.5,89.5),(15.5,89.0),(16.0,88.5),(16.0,88.5),(16.2,88.3),(16.5,88.0),
 (16.8,87.7),(16.9,87.2),(17.0,87.0),(17.1,86.8),(17.5,86.5),(17.8,86.0),(18.1,85.7),(18.6,85.4),
 (18.7,85.2),(19.1,85.2),(19.5,84.8),(20.0,84.5),(20.5,84.5),(21.0,84.0),(21.5,84.0),(21.8,83.8),
 (22.5,83.8),(22.75,83.65),(23.0,83.5),(23.25,83.75),(23.5,84.0),(24.0,84.1),(24.5,84.2),]  # Add the track data for Cyclone 
       
    },
{
        'name': 'Madi',
        'intensification_range': (0,13),  # Add the rapid intensification range for Cyclone here
        'track': [(10.0,84.0),(10.0,84.0),(10.1,84.0),(10.2,84.0),(10.3,84.0),(10.4,84.0),(10.45,84.05),(10.5,84.1),(10.5,84.1),(10.7,84.2),(10.8,84.3),
 (11.0,84.4),(11.0,84.5),(11.2,84.5),(11.5,84.6),(11.8,84.6),(12.0,84.6),(12.3,84.7),(12.6,84.7),
 (13.0,84.7),(13.2,84.7),(13.4,84.7),(13.6,84.7),(13.8,84.7),(14.0,84.7),(14.3,84.7),(14.4,84.7),
 (14.6,84.7),(14.7,84.7),(14.8,84.8),(14.8,84.8),(15.0,85.0),(15.3,85.3),(15.4,85.3),(15.7,85.3),
 (15.4,85.0),(15.1,84.8),(14.9,84.7),(14.6,84.6),(14.3,84.2),(14.0,83.8),(13.7,83.5),(13.5,83.4),
 (13.3,83.3),(13.1,83.5),(12.9,82.7),(12.7,82.35),(12.5,82.0),(12.0,81.5),(11.5,81.2),(11.0,80.7),(10.5,80.0),(10.25,78.9),
 (10.0,78.8),]  # Add the track data for Cyclone here
       
    },
{
        'name': 'Hudhud',
        'intensification_range': (33,42),  # Add the rapid intensification range for Cyclone here
        'track': [(11.5, 95.0), (11.7, 94.8), (11.85,94.4),(12.0, 94.0), (12.0,93.75),(12.0, 93.5),(12.1,93.25), (12.2, 93.0), (12.3, 92.9), (12.5, 92.5), (12.7, 91.7),
 (12.8, 91.0), (13.0, 90.5), (13.2, 90.2), (13.5, 89.6), (13.7, 89.2), (13.8, 89.0), (13.9, 88.8), (14.6, 88.6),
 (14.1, 88.4), (14.1, 88.1), (14.1, 87.9), (14.3, 87.7), (14.4, 87.6), (14.7, 87.2), (14.8, 87.0), (15.0, 86.8),
 (15.2, 86.7), (15.4, 86.5), (15.5, 86.4), (15.7, 86.1), (15.9, 85.7), (16.0, 85.4), (16.1, 85.1), (16.1, 85.0),
 (16.2, 84.8), (16.2, 84.8), (16.4, 84.7), (16.7, 84.4), (17.2, 84.2), (17.4, 83.8), (17.6, 83.4), (17.8, 83.0),
 (18.0, 82.7), (18.3, 82.5), (18.7, 82.3), (18.7, 82.3), (19.5, 81.5), (20.5, 81.5), (20.7, 81.5),(21.0,81.5), (21.3, 81.5),(21.8,81.5),
 (22.3, 81.5),(23.55,81.5), (24.8, 81.5), (25.1, 81.6), (25.6, 81.7), (26.3, 81.8),]  # Add the track data for Cyclone here
       
    },
{
        'name': 'Titli',
        'intensification_range': (8,23),  # Add the rapid intensification range for Cyclone here
        'track': [(14.0, 88.8), (14.0, 88.8),(14.15,88.5), (14.3, 88.2),(14.4,87.9), (14.5, 87.6),(14.6,87.35), (14.7, 87.1), (14.7, 86.9), (14.8, 86.7), (14.9, 86.6),
 (15.1, 86.4), (15.3, 86.2), (15.5, 86.0), (15.7, 85.8), (16.0, 85.8), (16.5, 85.8), (17.0, 85.6), (17.3, 85.4),
 (17.5, 85.3), (17.7, 85.2), (18.2, 85.1), (18.6, 84.7), (18.8, 84.4), (19.0, 84.1), (19.3, 83.8), (19.6, 83.8), 
 (19.9, 83.7), (20.1, 84.0), (20.3, 84.3),(20.4,84.5), (20.5, 84.7), (20.6, 84.9), (20.8, 85.2), (20.9, 85.5), (21.2, 86.1), (21.55,86.65),
 (21.9, 87.2), (22.1, 87.5),]  # Add the track data for Cyclone here
       
    },
{
        'name': 'Fani',
        'intensification_range': (23,38),  # Add the rapid intensification range for Cyclone here
        'track': [(2.7, 89.7),(2.7, 89.7), (3.0, 89.4), (3.1, 89.3), (3.2, 89.2), (3.45, 89), (3.7, 88.8), (4.1, 88.8), (4.5, 88.8),
 (4.9, 88.7), (5.2, 88.6), (5.4, 88.5), (5.9, 88.5),(6.3, 88.5), (6.6, 88.2), (6.9, 87.9), (7.3, 87.9), 
 (7.3, 87.9), (7.4, 87.8), (7.7, 87.5), (8.2, 87.0),(8.3, 86.9), (8.4, 86.9), (8.5, 86.9), (8.6, 86.9),
 (8.7, 86.9), (9.2, 86.9), (9.7, 86.8), (10.1, 86.7), (10.4, 86.7), (10.8, 86.6), (11.1, 86.5), (11.7, 86.5),
 (12.3, 86.2), (12.6, 85.7), (13.0, 85.3), (13.3, 84.7), (13.4, 84.5), (13.5, 84.4), (13.6, 84.2), (13.9, 84.0),
 (14.1, 83.9), (14.2, 83.9), (14.5, 84.1), (14.9, 84.1), (15.1, 84.1), (15.2, 84.1), (15.5, 84.2), (15.9, 84.5),
 (16.2, 84.6), (16.7, 84.8), (17.1, 84.8), (17.5, 84.8), (17.8, 84.9), (18.2, 85.0), (18.6, 85.2), (19.1, 85.5),
 (19.6, 85.7), (20.2, 85.9), (20.6, 86.0), (21.1, 86.5), (21.5, 86.7), (21.9, 87.1), (22.5, 87.9), (23.1, 88.2),
 (23.6,  88.8), (24.3, 89.3),(24.75,90.0), (25.2, 90.7),] # Add the track data for Cyclone here
       
    },
{
        'name': 'Bulbul',
        'intensification_range': (6,18),  # Add the rapid intensification range for Cyclone here
        'track': [(13.1, 91.5), (13.1, 91.0), (13.1, 90.7),(13.15,90.4), (13.2, 90.1),(13.25,89.95), (13.3, 89.8),(13.35,89.75), (13.4, 89.7), (13.4, 89.6), (13.4, 89.4),
 (13.45,89.35),(13.5, 89.3),(13.65,89.3), (13.8, 89.3),(14.0,89.3), (14.2, 89.3), (14.7, 89.3), (15.3, 88.7), (15.5, 88.4), (15.9, 88.0), (16.2, 87.9), 
 (16.4, 87.8), (16.6, 87.7), (16.9, 87.6), (17.2, 87.6), (17.6, 87.6), (18.1, 87.6), (18.5, 87.6), (19.2, 87.7), 
 (19.3, 87.6), (19.6, 87.7), (20.0, 87.6), (20.4, 87.6), (20.6, 87.8), (20.9, 87.9), (21.2, 88.1), (21.4, 88.3), 
 (21.6, 88.6), (21.9, 89.1), (22.1, 89.5), (22.2, 89.7), (22.3, 90.0), (22.4, 90.1), (22.5, 90.4),(22.6,90.8),(22.7, 91.2), (22.9,91.55),
 (23.1, 91.9),] # Add the track data for Cyclone here
       
    },
{
        'name': 'Amphan',
        'intensification_range': (16,29),  # Add the rapid intensification range for Cyclone here
        'track': [(10.4, 87.0), (10.7, 86.5), (10.9, 86.3), (10.9, 86.3), (10.9, 86.3), (11.0, 86.2), (11.1, 86.1), (11.3, 86.1), 
 (11.4, 86.0), (11.4, 86.0), (11.5, 86.0), (11.7, 86.0), (12.0, 86.0), (12.8, 86.2), (12.5, 86.1), (12.9, 86.4), 
 (13.2, 86.3), (13.3, 86.2), (13.4, 86.2), (13.7, 86.2), (14.0, 86.3), (14.5, 86.4), (14.9, 86.5), (15.2, 86.6), 
 (15.6, 86.7), (16.0, 86.8), (16.5, 86.9), (17.0, 86.9), (17.4, 87.0), (18.1, 87.1), (18.4, 87.2), (18.7, 87.2), 
 (19.1, 87.5), (19.8, 87.7), (20.6, 88.0), (21.4, 88.1), (21.9, 88.4), (22.7, 88.6), (23.3, 89.0), (24.2, 89.0), 
 (24.2, 89.3), (24.7, 89.5), (25.0, 89.6), (25.2,89.6), (25.4, 89.6),] # Add the track data for Cyclone here
       
    },    
{
        'name': 'Mocha',
        'intensification_range': (10,34),  # Add the rapid intensification range for Cyclone here
        'track': [(8.3, 89.5),(8.4,89.4), (8.5, 89.3),(8.5,89.15), (8.5, 89.0), (8.8, 88.9), (9.1, 88.7),(9.55,88.55), (10.0, 88.4),(10.4,88.3), (10.8, 88.2),(11,88.15), (11.2, 88.1),
 (11.4, 88.0), (11.6, 88.0), (11.8, 88.0), (12.2, 88.0), (12.5, 88.1), (12.7, 88.1), (12.9, 88.1), (13.2, 88.1),
 (13.6, 88.2), (14.0, 88.3), (14.3, 88.4), (14.6, 88.6), (14.8, 88.7), (15.1, 88.8), (15.2, 88.9), (15.4, 89.1),
 (15.7, 89.5), (16.0, 90.0), (16.4, 90.3), (16.9, 90.8), (17.4, 90.9), (17.9, 91.0), (18.3, 91.3), (18.7, 91.5),
 (19.3, 91.9), (19.9, 92.5), (20.5, 92.9), (21.1, 93.3), (21.8, 93.8), (22.7, 94.6), (23.5, 95.3), (23.9, 97.8),
 ] # Add the track data for Cyclone here
       
    }, 
{
        'name': 'Mala',
        'intensification_range': (17,32),  # Add the rapid intensification range for Cyclone here
        'track': [(9.5, 90.5), (9.5, 90.5), (9.5, 90.0), (10.0, 89.5), (10.0, 89.5), (10.0, 89.5), (10.0, 89.5), (10.5, 89.0), (10.5, 89.0),
 (11.0, 89.0), (11.0, 89.5), (11.5, 90.0), (12.0, 90.5), (12.0, 90.5), (12.0, 90.5), (12.0, 90.5), (12.5, 90.5), (12.5, 90.5),
 (12.5, 90.5), (13.0, 90.5), (13.0, 90.5), (13.0, 90.5), (13.5, 90.5), (14.0, 91.0), (14.5, 91.5), (15.0, 92.0), (15.3, 92.3), 
 (15.5, 92.5), (16.0, 93.0), (16.0, 93.0), (16.5, 93.5), (16.5, 93.5), (17.0, 94.0), (17.5, 94.5), (18.0, 95.0), (18.5, 95.5),
 (18.5, 95.5), (19.0, 96.0),] # Add the track data for Cyclone here
       
    },
{
        'name': 'Sidr',
        'intensification_range':  (0,12),  # Add the rapid intensification range for Cyclone here
        'track': [(10.0, 92.0), (10.0, 92.0), (10.0, 92.0), (10.5, 91.5), (10.5, 91.5), (10.5, 91.5), (10.5, 91.0), (11.0, 90.5), (11.0, 90.5),
      (11.5, 90.0), (11.5, 90.0), (11.5, 90.0), (11.5, 90.0), (12.0, 89.5), (12.0, 89.5), (12.0, 89.5), (13.0, 89.5), (13.0, 89.5),
      (13.0, 89.5), (13.5, 89.5), (14.0, 89.5), (14.5, 89.5), (14.5, 89.5), (15.0, 89.5), (15.5, 89.5), (16.0, 89.0), (16.0, 89.0), 
      (16.5, 89.0), (17.0, 89.0), (17.5, 89.0), (18.0, 89.0), (19.5, 89.0), (20.0, 89.0), (21.0, 89.0), (21.5, 89.5), (22.5, 90.5), 
      (23.5, 91.0), (23.5, 91.0), (24.5, 91.5),]
     
    },
{
        'name': 'Nargis',
        'intensification_range':  (0,12),  # Add the rapid intensification range for Cyclone here
        'track': [(12.0, 87.0), (12.0, 87.0), (12.0, 86.5), (12.0, 86.5), (12.0, 86.5), (12.5, 86.0), (13.0, 85.5), (13.0, 85.5), (13.0, 85.5),
        (13.0, 85.5), (13.0, 85.5), (13.0, 85.5), (13.0, 85.5), (13.0, 85.5), (13.0, 85.5), (13.0, 85.5), (13.5, 85.5), (13.5, 85.5), 
        (13.5, 85.5), (14.0, 85.5), (14.0, 85.5), (14.0, 85.5), (14.0, 86.0), (14.0, 86.0), (14.5, 86.5), (14.5, 86.5), (14.5, 87.0), 
        (14.5, 87.0), (15.0, 87.5), (15.0, 87.5), (15.0, 87.5), (15.5, 88.0), (15.5, 89.0), (16.0, 89.5), (16.0, 90.0), (16.0, 90.5), 
        (16.0, 91.0), (16.0, 91.5), (16.0, 92.0), (16.0, 92.5), (16.0, 93.0), (16.0, 93.5), (16.0, 94.0), (16.0, 94.3), (16.0, 95.0), 
        (16.5, 95.5), (16.5, 95.5), (16.5, 95.5), (17.0, 96.0), (17.5, 96.5), (18.0, 97.0),]
     
   },



    
    # Add more cyclone track data lists as needed
]


# Create a new figure
fig = plt.figure(figsize=(10, 10))

# Create a Cartopy map with a PlateCarree projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Set the extent based on the track data
ax.set_extent([lon_min, lon_max, lat_min, lat_max])

# Add grey color to land
ax.add_feature(cfeature.LAND, facecolor='lightgrey')

# Add skyblue color to ocean
ax.add_feature(cfeature.OCEAN, color='lightblue')

# Add coastline and borders
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')


# Plot all cyclone tracks
for cyclone_data in cyclone_tracks:
    track_data = cyclone_data['track']
    rapid_range = cyclone_data['intensification_range']
    cyclone_name = cyclone_data['name']
    
    lats, lons = zip(*track_data)
    start_idx, end_idx = rapid_range
    
    for i in range(len(lats) - 1):
        ax.plot(lons[0], lats[0], 'ko', markersize=5, transform=ccrs.PlateCarree())
        if start_idx <= i <= end_idx:
            color = 'red'
        else:
            color = 'green'
        
        ax.plot([lons[i], lons[i+1]], [lats[i], lats[i+1]], color=color, transform=ccrs.PlateCarree())
        
    # Add the cyclone name as text
    ax.text(lons[-1], lats[-1], cyclone_name, color='black', fontsize=15, ha='right', va='bottom', transform=ccrs.PlateCarree())

# Label latitude and longitude values on the axes
ax.set_xticks(range(lon_min, lon_max + 1, 5), crs=ccrs.PlateCarree())
ax.set_yticks(range(lat_min, lat_max + 1, 5), crs=ccrs.PlateCarree())
lon_formatter = LongitudeFormatter(zero_direction_label=True)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
# Label latitude and longitude
ax.set_xlabel('Longitude',fontsize=17)
ax.set_ylabel('Latitude',fontsize=17)
plt.subplots_adjust(left=0.1, right=0.96, top=.98, bottom=0.1)

plt.savefig('/DISK-0/gokul/ENGY/track_plot2.png',dpi=300)
# Show the plot
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_physical/ne_50m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in connect(self)
#    1446
# -> 1447             super().connect()
#    1448
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in connect(self)
#     955         if self._tunnel_host:
# --> 956             self._tunnel()
#     957
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _tunnel(self)
#     929             self.close()
# --> 930             raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
#     931         while True:
#
# OSError: Tunnel connection failed: 302 Moved Temporarily
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /tmp/ipykernel_77136/3693128538.py in <module>
#     202 plt.subplots_adjust(left=0.1, right=0.96, top=.98, bottom=0.1)
#     203
# --> 204 plt.savefig('/DISK-0/gokul/ENGY/track_plot2.png',dpi=300)
#     205 # Show the plot
#     206 plt.show()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     977 def savefig(*args, **kwargs):
#     978     fig = gcf()
# --> 979     res = fig.savefig(*args, **kwargs)
#     980     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     981     return res
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3044                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3045
# -> 3046             self.canvas.print_figure(fname, **kwargs)
#    3047
#    3048     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2317                 # force the figure dpi to 72), so we need to set it again here.
#    2318                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319                     result = print_method(
#    2320                         filename,
#    2321                         facecolor=facecolor,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2835
#    2836             self.patch.draw(renderer)
# -> 2837             mimage._draw_list_compositing_images(
#    2838                 renderer, self, artists, self.suppressComposite)
#    2839
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in draw(self, renderer, **kwargs)
#     536         self._done_img_factory = True
#     537
# --> 538         return super().draw(renderer=renderer, **kwargs)
#     539
#     540     def _update_title_position(self, renderer):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py in draw(self, renderer, *args, **kwargs)
#     149         except ValueError:
#     150             warnings.warn('Unable to determine extent. Defaulting to global.')
# --> 151         geoms = self._feature.intersecting_geometries(extent)
#     152
#     153         # Combine all the keyword args in priority order.
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in intersecting_geometries(self, extent)
#     303         """
#     304         self.scaler.scale_from_extent(extent)
# --> 305         return super().intersecting_geometries(extent)
#     306
#     307     def with_scale(self, new_scale):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in intersecting_geometries(self, extent)
#     106             extent_geom = sgeom.box(extent[0], extent[2],
#     107                                     extent[1], extent[3])
# --> 108             return (geom for geom in self.geometries() if
#     109                     geom is not None and extent_geom.intersects(geom))
#     110         else:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in geometries(self)
#     285         key = (self.name, self.category, self.scale)
#     286         if key not in _NATURAL_EARTH_GEOM_CACHE:
# --> 287             path = shapereader.natural_earth(resolution=self.scale,
#     288                                              category=self.category,
#     289                                              name=self.name)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/shapereader.py in natural_earth(resolution, category, name)
#     281     format_dict = {'config': config, 'category': category,
#     282                    'name': name, 'resolution': resolution}
# --> 283     return ne_downloader.path(format_dict)
#     284
#     285
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py in path(self, format_dict)
#     201         else:
#     202             # we need to download the file
# --> 203             result_path = self.acquire_resource(target_path, format_dict)
#     204
#     205         return result_path
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/shapereader.py in acquire_resource(self, target_path, format_dict)
#     335         url = self.url(format_dict)
#     336
# --> 337         shapefile_online = self._urlopen(url)
#     338
#     339         zfh = ZipFile(io.BytesIO(shapefile_online.read()), 'r')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py in _urlopen(self, url)
#     240         """
#     241         warnings.warn(f'Downloading: {url}', DownloadWarning)
# --> 242         return urlopen(url)
#     243
#     244     @staticmethod
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error Tunnel connection failed: 302 Moved Temporarily>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in connect(self)
#    1446
# -> 1447             super().connect()
#    1448
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in connect(self)
#     955         if self._tunnel_host:
# --> 956             self._tunnel()
#     957
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _tunnel(self)
#     929             self.close()
# --> 930             raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
#     931         while True:
#
# OSError: Tunnel connection failed: 302 Moved Temporarily
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2835
#    2836             self.patch.draw(renderer)
# -> 2837             mimage._draw_list_compositing_images(
#    2838                 renderer, self, artists, self.suppressComposite)
#    2839
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in draw(self, renderer, **kwargs)
#     536         self._done_img_factory = True
#     537
# --> 538         return super().draw(renderer=renderer, **kwargs)
#     539
#     540     def _update_title_position(self, renderer):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py in draw(self, renderer, *args, **kwargs)
#     149         except ValueError:
#     150             warnings.warn('Unable to determine extent. Defaulting to global.')
# --> 151         geoms = self._feature.intersecting_geometries(extent)
#     152
#     153         # Combine all the keyword args in priority order.
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in intersecting_geometries(self, extent)
#     303         """
#     304         self.scaler.scale_from_extent(extent)
# --> 305         return super().intersecting_geometries(extent)
#     306
#     307     def with_scale(self, new_scale):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in intersecting_geometries(self, extent)
#     106             extent_geom = sgeom.box(extent[0], extent[2],
#     107                                     extent[1], extent[3])
# --> 108             return (geom for geom in self.geometries() if
#     109                     geom is not None and extent_geom.intersects(geom))
#     110         else:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in geometries(self)
#     285         key = (self.name, self.category, self.scale)
#     286         if key not in _NATURAL_EARTH_GEOM_CACHE:
# --> 287             path = shapereader.natural_earth(resolution=self.scale,
#     288                                              category=self.category,
#     289                                              name=self.name)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/shapereader.py in natural_earth(resolution, category, name)
#     281     format_dict = {'config': config, 'category': category,
#     282                    'name': name, 'resolution': resolution}
# --> 283     return ne_downloader.path(format_dict)
#     284
#     285
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py in path(self, format_dict)
#     201         else:
#     202             # we need to download the file
# --> 203             result_path = self.acquire_resource(target_path, format_dict)
#     204
#     205         return result_path
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/shapereader.py in acquire_resource(self, target_path, format_dict)
#     335         url = self.url(format_dict)
#     336
# --> 337         shapefile_online = self._urlopen(url)
#     338
#     339         zfh = ZipFile(io.BytesIO(shapefile_online.read()), 'r')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py in _urlopen(self, url)
#     240         """
#     241         warnings.warn(f'Downloading: {url}', DownloadWarning)
# --> 242         return urlopen(url)
#     243
#     244     @staticmethod
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error Tunnel connection failed: 302 Moved Temporarily>

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from matplotlib.patches import Rectangle

# Define the coordinates of the Bay of Bengal region
lon_min, lon_max = 70, 105
lat_min, lat_max = 0, 35

# Provided track data
track_data = [
    (10.4, 87.0), (10.7, 86.5), (10.9, 86.3), (10.9, 86.3), (10.9, 86.3), (11.0, 86.2), (11.1, 86.1), (11.3, 86.1), 
    (11.4, 86.0), (11.4, 86.0), (11.5, 86.0), (11.7, 86.0), (12.0, 86.0), (12.8, 86.2), (12.5, 86.1), (12.9, 86.4), 
    (13.2, 86.3), (13.3, 86.2), (13.4, 86.2), (13.7, 86.2), (14.0, 86.3), (14.5, 86.4), (14.9, 86.5), (15.2, 86.6), 
    (15.6, 86.7), (16.0, 86.8), (16.5, 86.9), (17.0, 86.9), (17.4, 87.0), (18.1, 87.1), (18.4, 87.2), (18.7, 87.2), 
    (19.1, 87.5), (19.8, 87.7), (20.6, 88.0), (21.4, 88.1), (21.9, 88.4), (22.7, 88.6), (23.3, 89.0), (24.2, 89.0), 
    (24.2, 89.3), (24.7, 89.5), (25.0, 89.6), (25.2,89.6), (25.4, 89.6),
]

# Extract latitude and longitude from the track_data
lats, lons = zip(*track_data)

# Create a new figure
fig = plt.figure(figsize=(10, 10))

# Create a Cartopy map with a PlateCarree projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Set the extent based on the track data
ax.set_extent([lon_min, lon_max, lat_min, lat_max])

# Add grey color to land
ax.add_feature(cfeature.LAND, facecolor='lightgrey')

# Add skyblue color to ocean
ax.add_feature(cfeature.OCEAN, color='lightblue')

# Add coastline and borders
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Plot the track data with boxes and color changes
box_size = 12.5 / 2  # Half of the box size
for i, (lat, lon) in enumerate(zip(lats, lons)):
    box_color = 'blue' if not (16 <= i <= 29) else 'red'
    box = Rectangle((lon - box_size, lat - box_size), 12.5, 12.5, fill=False, edgecolor=box_color, linewidth=1.5, transform=ccrs.PlateCarree())
    ax.add_patch(box)
    if 16 <= i <= 29:
        ax.plot(lon, lat, 'ro', markersize=5, transform=ccrs.PlateCarree())
    else:
        ax.plot(lon, lat, 'ko', markersize=5, transform=ccrs.PlateCarree())

# Plot the track line from stages 16 to 29 in red
ax.plot(lons[16:30], lats[16:30], color='red', transform=ccrs.PlateCarree())

# Label latitude and longitude values on the axes
ax.set_xticks(range(lon_min, lon_max + 1, 5), crs=ccrs.PlateCarree())
ax.set_yticks(range(lat_min, lat_max + 1, 5), crs=ccrs.PlateCarree())
lon_formatter = LongitudeFormatter(zero_direction_label=True)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
# Label latitude and longitude
ax.set_xlabel('Longitude',fontsize=17)
ax.set_ylabel('Latitude',fontsize=17)
plt.subplots_adjust(left=0.1, right=0.96, top=.98, bottom=0.1)
plt.savefig('/home/gokulsuresh/Downloads/Quasi-track-amphan.png',dpi=300)
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# Define the coordinates of the Bay of Bengal region
lon_min, lon_max = 70, 105
lat_min, lat_max = 0, 35

# Define track data for Cyclone Amphan
amphan_track = {
    'name': 'Amphan',
    'intensification_range': (16, 29),
    'track': [(10.4, 87.0), (10.7, 86.5), (10.9, 86.3), (10.9, 86.3), (10.9, 86.3), (11.0, 86.2), (11.1, 86.1), (11.3, 86.1), 
              (11.4, 86.0), (11.4, 86.0), (11.5, 86.0), (11.7, 86.0), (12.0, 86.0), (12.8, 86.2), (12.5, 86.1), (12.9, 86.4), 
              (13.2, 86.3), (13.3, 86.2), (13.4, 86.2), (13.7, 86.2), (14.0, 86.3), (14.5, 86.4), (14.9, 86.5), (15.2, 86.6), 
              (15.6, 86.7), (16.0, 86.8), (16.5, 86.9), (17.0, 86.9), (17.4, 87.0), (18.1, 87.1), (18.4, 87.2), (18.7, 87.2), 
              (19.1, 87.5), (19.8, 87.7), (20.6, 88.0), (21.4, 88.1), (21.9, 88.4), (22.7, 88.6), (23.3, 89.0), (24.2, 89.0), 
              (24.2, 89.3), (24.7, 89.5), (25.0, 89.6), (25.2, 89.6), (25.4, 89.6)]
}

track_data = amphan_track['track']

# Extract latitudes and longitudes
lats, lons = zip(*track_data)

# Calculate the bounding box
min_lat, max_lat = min(lats), max(lats)
min_lon, max_lon = min(lons), max(lons)

# Add an extension of 5.5 degrees in all directions
lon_extension = 5.5
lat_extension = 5.5

lon_min, lon_max = min_lon - lon_extension, max_lon + lon_extension
lat_min, lat_max = min_lat - lat_extension, max_lat + lat_extension

# Create a new figure
fig = plt.figure(figsize=(10, 10))

# Create a Cartopy map with a PlateCarree projection
ax = plt.axes(projection=ccrs.PlateCarree())

# Set the extent based on the adjusted track data
ax.set_extent([lon_min, lon_max, lat_min, lat_max])

# Add grey color to land
ax.add_feature(cfeature.LAND, facecolor='lightgrey')

# Add skyblue color to ocean
ax.add_feature(cfeature.OCEAN, color='lightblue')

# Add coastline and borders
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Extract Amphan's track data
track_data = amphan_track['track']
rapid_range = amphan_track['intensification_range']
cyclone_name = amphan_track['name']

lats, lons = zip(*track_data)
start_idx, end_idx = rapid_range

for i in range(len(lats) - 1):
    ax.plot(lons[0], lats[0], 'ko', markersize=5, transform=ccrs.PlateCarree())
    if start_idx <= i <= end_idx:
        color = 'red'
    else:
        color = 'green'
    
    ax.plot([lons[i], lons[i+1]], [lats[i], lats[i+1]], color=color, transform=ccrs.PlateCarree())

# Add the cyclone name as text
ax.text(lons[-1], lats[-1], cyclone_name, color='black', fontsize=15, ha='right', va='bottom', transform=ccrs.PlateCarree())

ax.set_xticks(range(int(lon_min), int(lon_max) + 1, 5), crs=ccrs.PlateCarree())
ax.set_yticks(range(int(lat_min), int(lat_max) + 1, 5), crs=ccrs.PlateCarree())
lon_formatter = LongitudeFormatter(zero_direction_label=True)
lon_formatter._style = {'size': 17}
lat_formatter = LatitudeFormatter()
lat_formatter._style = {'size': 17} 
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

# Label latitude and longitude
ax.set_xlabel('Longitude', fontsize=17)
ax.set_ylabel('Latitude', fontsize=17)
plt.subplots_adjust(left=0.1, right=0.96, top=.98, bottom=0.1)


ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)

plt.savefig('/home/gokulsuresh/Downloads/amphan_track_plot.png', dpi=300)
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in connect(self)
#    1446
# -> 1447             super().connect()
#    1448
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in connect(self)
#     955         if self._tunnel_host:
# --> 956             self._tunnel()
#     957
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _tunnel(self)
#     929             self.close()
# --> 930             raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
#     931         while True:
#
# OSError: Tunnel connection failed: 302 Moved Temporarily
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /tmp/ipykernel_189299/2702066245.py in <module>
#      93 ax.yaxis.set_major_formatter(lat_formatter)
#      94
# ---> 95 plt.savefig('/home/gokulsuresh/Downloads/amphan_track_plot.png', dpi=300)
#      96 # Show the plot
#      97 plt.show()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     977 def savefig(*args, **kwargs):
#     978     fig = gcf()
# --> 979     res = fig.savefig(*args, **kwargs)
#     980     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     981     return res
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3044                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3045
# -> 3046             self.canvas.print_figure(fname, **kwargs)
#    3047
#    3048     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2317                 # force the figure dpi to 72), so we need to set it again here.
#    2318                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319                     result = print_method(
#    2320                         filename,
#    2321                         facecolor=facecolor,
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2835
#    2836             self.patch.draw(renderer)
# -> 2837             mimage._draw_list_compositing_images(
#    2838                 renderer, self, artists, self.suppressComposite)
#    2839
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in draw(self, renderer, **kwargs)
#     536         self._done_img_factory = True
#     537
# --> 538         return super().draw(renderer=renderer, **kwargs)
#     539
#     540     def _update_title_position(self, renderer):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py in draw(self, renderer, *args, **kwargs)
#     149         except ValueError:
#     150             warnings.warn('Unable to determine extent. Defaulting to global.')
# --> 151         geoms = self._feature.intersecting_geometries(extent)
#     152
#     153         # Combine all the keyword args in priority order.
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in intersecting_geometries(self, extent)
#     303         """
#     304         self.scaler.scale_from_extent(extent)
# --> 305         return super().intersecting_geometries(extent)
#     306
#     307     def with_scale(self, new_scale):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in intersecting_geometries(self, extent)
#     106             extent_geom = sgeom.box(extent[0], extent[2],
#     107                                     extent[1], extent[3])
# --> 108             return (geom for geom in self.geometries() if
#     109                     geom is not None and extent_geom.intersects(geom))
#     110         else:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in geometries(self)
#     285         key = (self.name, self.category, self.scale)
#     286         if key not in _NATURAL_EARTH_GEOM_CACHE:
# --> 287             path = shapereader.natural_earth(resolution=self.scale,
#     288                                              category=self.category,
#     289                                              name=self.name)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/shapereader.py in natural_earth(resolution, category, name)
#     281     format_dict = {'config': config, 'category': category,
#     282                    'name': name, 'resolution': resolution}
# --> 283     return ne_downloader.path(format_dict)
#     284
#     285
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py in path(self, format_dict)
#     201         else:
#     202             # we need to download the file
# --> 203             result_path = self.acquire_resource(target_path, format_dict)
#     204
#     205         return result_path
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/shapereader.py in acquire_resource(self, target_path, format_dict)
#     335         url = self.url(format_dict)
#     336
# --> 337         shapefile_online = self._urlopen(url)
#     338
#     339         zfh = ZipFile(io.BytesIO(shapefile_online.read()), 'r')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py in _urlopen(self, url)
#     240         """
#     241         warnings.warn(f'Downloading: {url}', DownloadWarning)
# --> 242         return urlopen(url)
#     243
#     244     @staticmethod
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error Tunnel connection failed: 302 Moved Temporarily>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in connect(self)
#    1446
# -> 1447             super().connect()
#    1448
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in connect(self)
#     955         if self._tunnel_host:
# --> 956             self._tunnel()
#     957
#
# /usr/local/anaconda3/lib/python3.9/http/client.py in _tunnel(self)
#     929             self.close()
# --> 930             raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
#     931         while True:
#
# OSError: Tunnel connection failed: 302 Moved Temporarily
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2835
#    2836             self.patch.draw(renderer)
# -> 2837             mimage._draw_list_compositing_images(
#    2838                 renderer, self, artists, self.suppressComposite)
#    2839
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py in draw(self, renderer, **kwargs)
#     536         self._done_img_factory = True
#     537
# --> 538         return super().draw(renderer=renderer, **kwargs)
#     539
#     540     def _update_title_position(self, renderer):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/mpl/feature_artist.py in draw(self, renderer, *args, **kwargs)
#     149         except ValueError:
#     150             warnings.warn('Unable to determine extent. Defaulting to global.')
# --> 151         geoms = self._feature.intersecting_geometries(extent)
#     152
#     153         # Combine all the keyword args in priority order.
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in intersecting_geometries(self, extent)
#     303         """
#     304         self.scaler.scale_from_extent(extent)
# --> 305         return super().intersecting_geometries(extent)
#     306
#     307     def with_scale(self, new_scale):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in intersecting_geometries(self, extent)
#     106             extent_geom = sgeom.box(extent[0], extent[2],
#     107                                     extent[1], extent[3])
# --> 108             return (geom for geom in self.geometries() if
#     109                     geom is not None and extent_geom.intersects(geom))
#     110         else:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/feature/__init__.py in geometries(self)
#     285         key = (self.name, self.category, self.scale)
#     286         if key not in _NATURAL_EARTH_GEOM_CACHE:
# --> 287             path = shapereader.natural_earth(resolution=self.scale,
#     288                                              category=self.category,
#     289                                              name=self.name)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/shapereader.py in natural_earth(resolution, category, name)
#     281     format_dict = {'config': config, 'category': category,
#     282                    'name': name, 'resolution': resolution}
# --> 283     return ne_downloader.path(format_dict)
#     284
#     285
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py in path(self, format_dict)
#     201         else:
#     202             # we need to download the file
# --> 203             result_path = self.acquire_resource(target_path, format_dict)
#     204
#     205         return result_path
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/shapereader.py in acquire_resource(self, target_path, format_dict)
#     335         url = self.url(format_dict)
#     336
# --> 337         shapefile_online = self._urlopen(url)
#     338
#     339         zfh = ZipFile(io.BytesIO(shapefile_online.read()), 'r')
#
# /usr/local/anaconda3/lib/python3.9/site-packages/cartopy/io/__init__.py in _urlopen(self, url)
#     240         """
#     241         warnings.warn(f'Downloading: {url}', DownloadWarning)
# --> 242         return urlopen(url)
#     243
#     244     @staticmethod
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# /usr/local/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error Tunnel connection failed: 302 Moved Temporarily>
