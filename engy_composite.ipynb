# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps1 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/aila_3_q/eke.txt": 0,
    # ... add more entries as needed
}
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps2 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/zke.txt":0,
    "/DISK-0/gokul/ENGY/dat2/aila_3_q/zke.txt": 0,
    # ... add more entries as needed
}
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps3 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/zape.txt":0,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/zape.txt": 0,
     "/DISK-0/gokul/ENGY/dat2/aila_3_q/zape.txt": 0,
    # ... add more entries as needed
}
file_starting_timesteps4 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/aila_3_q/eape.txt": 0,
    # ... add more entries as needed
}
# Initialize an empty list to store data from each file
data_list1 = []
data_list2 = []
data_list3 = []
data_list4 = []
# Number of timesteps to extract from each file
num_timesteps_to_extract = 15

# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps1.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list1.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array1 = np.array(data_list1)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step1 = np.mean(data_array1, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step1)






# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps2.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list2.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array2 = np.array(data_list2)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step2 = np.mean(data_array2, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step2)


# Initialize an empty list to store data from each file




# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps3.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list3.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array3 = np.array(data_list3)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step3 = np.mean(data_array3, axis=0)


# Print or use the mean_at_each_step as needed
print(mean_at_each_step3)



# Initialize an empty list to store data from each file




# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps4.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list4.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array4 = np.array(data_list4)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step4 = np.mean(data_array4, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step4)


# Generate timesteps (assuming your data starts from timestep 0)
timesteps = 3*np.arange(1,16)






# Plot the mean values
plt.figure(figsize=(8, 6))

# Plot the mean values with appropriate line styles, colors, and markers
plt.plot(timesteps, mean_at_each_step1, label='EKE', linewidth=2, linestyle='-', color='red', marker='o', markersize=7)
plt.plot(timesteps, mean_at_each_step2, label='ZKE', linewidth=2, linestyle='-', color='green', marker='s', markersize=7)
plt.plot(timesteps, mean_at_each_step3, label='ZAPE', linewidth=2, linestyle='-', color='blue', marker='^', markersize=7)
plt.plot(timesteps, mean_at_each_step4, label='EAPE', linewidth=2, linestyle='-', color='black', marker='D', markersize=7)


# Add labels and title with appropriate font sizes
plt.xlabel('Relative Time (Hours)', fontsize=19)
plt.ylabel('Energy (J/m²)', fontsize=19)
plt.title('Non-RI TCs(quasi-Lagrangian)', fontsize=21)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
# Add legend with appropriate font size
plt.legend(fontsize=12)
# Set y-axis in scientific notation with an exponent of 10^3
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
# Access the y-axis tick labels
y_formatter = plt.gca().get_yaxis().get_major_formatter()
plt.rc('font', size=17)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)
#plt.xticks(np.arange(1, 21) )


# Set a tight layout for better spacing
plt.tight_layout()

# Save the plot as a high-quality image for inclusion in the research paper
#plt.savefig('research_plot.png', dpi=300)

# Calculate the standard error of the mean along axis 0 (columns)
std_error_at_each_step1 = np.std(data_array1, axis=0) / np.sqrt(data_array1.shape[0])
std_error_at_each_step2 = np.std(data_array2, axis=0) / np.sqrt(data_array2.shape[0])
std_error_at_each_step3 = np.std(data_array3, axis=0) / np.sqrt(data_array3.shape[0])
std_error_at_each_step4 = np.std(data_array4, axis=0) / np.sqrt(data_array4.shape[0])


# Plot the mean values with error bars representing the standard error
# Plot the mean values with error bars representing the standard error for each energy term
#plt.errorbar(timesteps, mean_at_each_step1, yerr=std_error_at_each_step1, label='EKE', linewidth=1, linestyle='-', color='red', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step2, yerr=std_error_at_each_step2, label='ZKE', linewidth=1, linestyle='-', color='green', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step3, yerr=std_error_at_each_step3, label='ZAPE', linewidth=1, linestyle='-', color='blue', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step4, yerr=std_error_at_each_step4, label='EAPE', linewidth=1, linestyle='-', color='black', marker='None',capsize=4)
# Shade the region between the upper and lower bounds of standard error
plt.fill_between(timesteps, mean_at_each_step1 - std_error_at_each_step1, mean_at_each_step1 + std_error_at_each_step1, color='red', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step2 - std_error_at_each_step2, mean_at_each_step2 + std_error_at_each_step2, color='green', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step3 - std_error_at_each_step3, mean_at_each_step3 + std_error_at_each_step3, color='blue', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step4 - std_error_at_each_step4, mean_at_each_step4 + std_error_at_each_step4, color='black', alpha=0.3)


plt.xticks(timesteps[::2])
plt.ylim(0,6e5)
plt.savefig('nri_composite_engy.png', dpi=300)
# Show the plot
plt.show()
#Assuming you have already calculated mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4
# Define the directory path
directory = 'Composite_values'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
# Define filenames to save the mean values
file_names = ['Composite_values/NRI_EKE.txt', 'Composite_values/NRI_ZKE.txt', 'Composite_values/NRI_ZAPE.txt', 'Composite_values/NRI_EAPE.txt']

# Save mean values to separate files
for i, mean_at_each_step in enumerate([mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4]):
    np.savetxt(file_names[i], mean_at_each_step)
# Out:
# [197165.99641102 209177.16739433 225442.65783259 242402.26937192
#  256943.21317332 273137.38478082 291598.06804998 312916.00223098
#  337898.89290929 350716.65736181 363568.63162347 369776.08414633
#  382251.75155061 389645.16509856 391431.63442612]
# [376515.47544643 379759.15736607 378830.80803571 374604.14397321
#  387988.42745536 394208.1796875  395405.71205357 389231.13058036
#  399857.38616071 401799.6640625  399135.97544643 393734.87276786
#  408606.33482143 415220.83258929 418403.56696429]
# [16953.12638108 18427.01276053 18223.37935388 16659.14727715
#  15748.87741317 15167.63293943 15198.40357235 15504.97338179
#  18149.18149725 20119.45611286 19272.57554679 18809.52407434
#  19545.38727769 19676.07456178 19710.07815709]
# [26678.03115954 28706.50268443 28641.10938735 29557.3977694
#  29055.64953994 29125.67953182 29895.75144477 32026.90620157
#  38607.6639923  43956.87773741 44248.60548267 43825.01809085
#  43219.68466094 41627.978848   41680.73805843]

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps1 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/eke.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/eke.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/eke.txt": 26,
    "/DISK-0/gokul/ENGY/data/titli_3_q/eke.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/eke.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/eke.txt": 16,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/eke.txt": 2,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/eke.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/eke.txt": 16,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/eke.txt": 6,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/eke.txt": 3,
    # ... add more entries as needed
}
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps2 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/zke.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/zke.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/zke.txt": 26,
    "/DISK-0/gokul/ENGY/data/titli_3_q/zke.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/zke.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/zke.txt": 16,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/zke.txt": 2,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/zke.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/zke.txt": 16,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/zke.txt": 6,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/zke.txt": 3,
    # ... add more entries as needed
}
file_starting_timesteps3 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/zape.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/zape.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/zape.txt": 26,
    "/DISK-0/gokul/ENGY/data/titli_3_q/zape.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/zape.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/zape.txt": 16,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/zape.txt": 2,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/zape.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/zape.txt": 16,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/zape.txt": 6,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/zape.txt": 3,
    # ... add more entries as needed
}
file_starting_timesteps4 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/eape.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/eape.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/eape.txt": 26,
    "/DISK-0/gokul/ENGY/data/titli_3_q/eape.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/eape.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/eape.txt": 16,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/eape.txt": 2,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/eape.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/eape.txt": 16,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/eape.txt": 6,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/eape.txt": 3,
    # ... add more entries as needed
}
# Initialize an empty list to store data from each file
data_list1 = []
data_list2 = []
data_list3 = []
data_list4 = []

# Number of timesteps to extract from each file
num_timesteps_to_extract = 15

# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps1.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list1.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array1 = np.array(data_list1)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step1 = np.mean(data_array1, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step1)

# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps2.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list2.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array2 = np.array(data_list2)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step2 = np.mean(data_array2, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step2)
# Define the dictionary with file names and corresponding starting timesteps



# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps3.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list3.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array3 = np.array(data_list3)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step3 = np.mean(data_array3, axis=0)
# Print or use the mean_at_each_step as needed
print(mean_at_each_step3)

# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps4.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list4.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array4 = np.array(data_list4)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step4 = np.mean(data_array4, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step4)

# Generate timesteps (assuming your data starts from timestep 0)
timesteps = 3*np.arange(1,16)
# Plot the mean values
plt.figure(figsize=(8, 6))

# Plot the mean values with appropriate line styles, colors, and markers
plt.plot(timesteps, mean_at_each_step1, label='EKE', linewidth=2, linestyle='-', color='red', marker='o', markersize=7)
plt.plot(timesteps, mean_at_each_step2, label='ZKE', linewidth=2, linestyle='-', color='green', marker='s', markersize=7)
plt.plot(timesteps, mean_at_each_step3, label='ZAPE', linewidth=2, linestyle='-', color='blue', marker='^', markersize=7)
plt.plot(timesteps, mean_at_each_step4, label='EAPE', linewidth=2, linestyle='-', color='black', marker='D', markersize=7)


# Add labels and title with appropriate font sizes
plt.xlabel('Relative Time (Hours)', fontsize=19)
plt.ylabel('Energy (J/m²)', fontsize=17)
plt.title('RI TCs(quasi-Lagrangian)', fontsize=21)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)

# Add legend with appropriate font size
plt.legend(fontsize=12)
# Set y-axis in scientific notation with an exponent of 10^3
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
# Access the y-axis tick labels
y_formatter = plt.gca().get_yaxis().get_major_formatter()
plt.rc('font', size=17)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)
#plt.xticks(np.arange(1, 21) )


# Set a tight layout for better spacing
plt.tight_layout()
# Calculate the standard error of the mean along axis 0 (columns)
std_error_at_each_step1 = np.std(data_array1, axis=0) / np.sqrt(data_array1.shape[0])
std_error_at_each_step2 = np.std(data_array2, axis=0) / np.sqrt(data_array2.shape[0])
std_error_at_each_step3 = np.std(data_array3, axis=0) / np.sqrt(data_array3.shape[0])
std_error_at_each_step4 = np.std(data_array4, axis=0) / np.sqrt(data_array4.shape[0])


# Plot the mean values with error bars representing the standard error
# Plot the mean values with error bars representing the standard error for each energy term
#plt.errorbar(timesteps, mean_at_each_step1, yerr=std_error_at_each_step1, label='EKE', linewidth=1, linestyle='-', color='red', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step2, yerr=std_error_at_each_step2, label='ZKE', linewidth=1, linestyle='-', color='green', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step3, yerr=std_error_at_each_step3, label='ZAPE', linewidth=1, linestyle='-', color='blue', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step4, yerr=std_error_at_each_step4, label='EAPE', linewidth=1, linestyle='-', color='black', marker='None',capsize=4)
# Shade the region between the upper and lower bounds of standard error
plt.fill_between(timesteps, mean_at_each_step1 - std_error_at_each_step1, mean_at_each_step1 + std_error_at_each_step1, color='red', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step2 - std_error_at_each_step2, mean_at_each_step2 + std_error_at_each_step2, color='green', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step3 - std_error_at_each_step3, mean_at_each_step3 + std_error_at_each_step3, color='blue', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step4 - std_error_at_each_step4, mean_at_each_step4 + std_error_at_each_step4, color='black', alpha=0.3)

# Save the plot as a high-quality image for inclusion in the research paper
#plt.savefig('research_plot.png', dpi=300)

# Set x-axis ticks at alternative timesteps
plt.xticks(timesteps[::2])
plt.ylim(0,6e5)
plt.savefig('ri_composite_engy.png', dpi=300)
# Show the plot
plt.show()
#Assuming you have already calculated mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4
# Define the directory path
directory = 'Composite_values'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
# Define filenames to save the mean values
file_names = ['Composite_values/RI_EKE.txt', 'Composite_values/RI_ZKE.txt', 'Composite_values/RI_ZAPE.txt', 'Composite_values/RI_EAPE.txt']

# Save mean values to separate files
for i, mean_at_each_step in enumerate([mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4]):
    np.savetxt(file_names[i], mean_at_each_step)
# Out:
# [244421.48960163 262803.64628701 277400.90334934 299212.97856978
#  311059.26490233 333594.56620495 355176.31628058 378636.86661429
#  398756.77812004 417532.44705023 428665.0742479  443443.98739595
#  454877.1036632  464815.92537344 469819.51859928]
# [287435.44794964 290794.01292087 294442.69700705 305302.3906353
#  314857.58915999 329043.27597989 332128.23828121 341792.42149108
#  348730.44397446 348264.17292689 345846.96251839 348681.93475951
#  354719.56881341 366392.18031034 372948.78333513]
# [15388.14905275 15664.06292048 15775.20613361 16645.15155718
#  17256.47798735 17421.70296204 18302.06408818 19771.9526234
#  20307.02427738 20481.94583214 20781.38339022 22685.71549261
#  23165.2444678  24408.89524097 25320.99059337]
# [27596.36111412 30560.03276888 31943.19204176 32398.91301537
#  31996.72797409 33687.42965173 35168.19904221 39300.41151142
#  40089.7145427  41347.74302398 42724.00809022 43789.94640626
#  44519.796225   43292.20550626 44627.3693281 ]

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps1 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/aila_3_e/eke.txt": 0,
    # ... add more entries as needed
}
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps2 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/zke.txt":0,
    "/DISK-0/gokul/ENGY/dat2/aila_3_e/zke.txt": 0,
    # ... add more entries as needed
}
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps3 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/zape.txt":0,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/zape.txt": 0,
     "/DISK-0/gokul/ENGY/dat2/aila_3_e/zape.txt": 0,
    # ... add more entries as needed
}
file_starting_timesteps4 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/aila_3_e/eape.txt": 0,
    # ... add more entries as needed
}
# Initialize an empty list to store data from each file
data_list1 = []
data_list2 = []
data_list3 = []
data_list4 = []
# Number of timesteps to extract from each file
num_timesteps_to_extract = 15

# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps1.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list1.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array1 = np.array(data_list1)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step1 = np.mean(data_array1, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step1)






# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps2.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list2.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array2 = np.array(data_list2)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step2 = np.mean(data_array2, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step2)


# Initialize an empty list to store data from each file




# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps3.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list3.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array3 = np.array(data_list3)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step3 = np.mean(data_array3, axis=0)


# Print or use the mean_at_each_step as needed
print(mean_at_each_step3)



# Initialize an empty list to store data from each file




# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps4.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list4.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array4 = np.array(data_list4)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step4 = np.mean(data_array4, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step4)


# Generate timesteps (assuming your data starts from timestep 0)
timesteps = 3*np.arange(1,16)






# Plot the mean values
plt.figure(figsize=(8, 6))

# Plot the mean values with appropriate line styles, colors, and markers
plt.plot(timesteps, mean_at_each_step1, label='EKE', linewidth=2, linestyle='-', color='red', marker='o', markersize=7)
plt.plot(timesteps, mean_at_each_step2, label='ZKE', linewidth=2, linestyle='-', color='green', marker='s', markersize=7)
plt.plot(timesteps, mean_at_each_step3, label='ZAPE', linewidth=2, linestyle='-', color='blue', marker='^', markersize=7)
plt.plot(timesteps, mean_at_each_step4, label='EAPE', linewidth=2, linestyle='-', color='black', marker='D', markersize=7)


# Add labels and title with appropriate font sizes
plt.xlabel('Relative Time (Hours)', fontsize=19)
plt.ylabel('Energy (J/m²)', fontsize=19)
plt.title('Non-RI TCs(Eulerian)', fontsize=21)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)

# Add legend with appropriate font size
plt.legend(fontsize=12)
# Set y-axis in scientific notation with an exponent of 10^3
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
# Access the y-axis tick labels
y_formatter = plt.gca().get_yaxis().get_major_formatter()
plt.rc('font', size=17)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)
#plt.xticks(np.arange(1, 21) )


# Set a tight layout for better spacing
plt.tight_layout()
# Calculate the standard error of the mean along axis 0 (columns)
std_error_at_each_step1 = np.std(data_array1, axis=0) / np.sqrt(data_array1.shape[0])
std_error_at_each_step2 = np.std(data_array2, axis=0) / np.sqrt(data_array2.shape[0])
std_error_at_each_step3 = np.std(data_array3, axis=0) / np.sqrt(data_array3.shape[0])
std_error_at_each_step4 = np.std(data_array4, axis=0) / np.sqrt(data_array4.shape[0])


# Plot the mean values with error bars representing the standard error
# Plot the mean values with error bars representing the standard error for each energy term
#plt.errorbar(timesteps, mean_at_each_step1, yerr=std_error_at_each_step1, label='EKE', linewidth=1, linestyle='-', color='red', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step2, yerr=std_error_at_each_step2, label='ZKE', linewidth=1, linestyle='-', color='green', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step3, yerr=std_error_at_each_step3, label='ZAPE', linewidth=1, linestyle='-', color='blue', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step4, yerr=std_error_at_each_step4, label='EAPE', linewidth=1, linestyle='-', color='black', marker='None',capsize=4)
# Shade the region between the upper and lower bounds of standard error
plt.fill_between(timesteps, mean_at_each_step1 - std_error_at_each_step1, mean_at_each_step1 + std_error_at_each_step1, color='red', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step2 - std_error_at_each_step2, mean_at_each_step2 + std_error_at_each_step2, color='green', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step3 - std_error_at_each_step3, mean_at_each_step3 + std_error_at_each_step3, color='blue', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step4 - std_error_at_each_step4, mean_at_each_step4 + std_error_at_each_step4, color='black', alpha=0.3)

# Save the plot as a high-quality image for inclusion in the research paper
#plt.savefig('research_plot.png', dpi=300)

plt.xticks(timesteps[::2])
plt.ylim(0,6e5)
plt.savefig('nri_composite_engy_eulerian.png', dpi=300)
# Show the plot
plt.show()
#Assuming you have already calculated mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4
# Define the directory path
directory = 'Composite_values'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
# Define filenames to save the mean values
file_names = ['Composite_values/NRI_EKE_E.txt', 'Composite_values/NRI_ZKE_E.txt', 'Composite_values/NRI_ZAPE_E.txt', 'Composite_values/NRI_EAPE_E.txt']

# Save mean values to separate files
for i, mean_at_each_step in enumerate([mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4]):
    np.savetxt(file_names[i], mean_at_each_step)
# Out:
# [160301.01103442 169125.50591997 182418.61745715 194983.52610639
#  206460.43824298 215179.05224647 226025.63994271 239205.55363808
#  256315.05970444 263358.49953549 269517.55698238 272628.78392424
#  278711.51506901 281070.55957828 280838.62487759]
# [322028.39285714 326667.72433036 323869.65066964 320947.76004464
#  329008.95758929 334205.69754464 336157.58816964 338953.70758929
#  348750.92857143 351587.82254464 350410.53125    351680.06808036
#  361263.13839286 371431.55133929 377204.83705357]
# [40973.48760357 45806.90767644 43555.44142449 37418.59906473
#  33944.69312899 33077.90005087 32265.77249946 31981.48194497
#  39103.22976878 42542.64075075 40216.5183502  36053.01079775
#  34324.60271043 34186.68495289 33010.3144866 ]
# [53017.3312453  60756.33153163 61561.15684713 57880.24132789
#  51836.71871249 46581.78496589 44634.94033568 47574.43603437
#  58334.96604345 65770.59201109 67380.39235844 63461.86177985
#  57308.6174719  51219.58907627 49140.13240882]

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps1 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/eke.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/eke.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/eke.txt": 26,
    "/DISK-0/gokul/ENGY/data/titli_3_e/eke.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/eke.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/eke.txt": 16,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/eke.txt": 2,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/eke.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/eke.txt": 16,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/eke.txt": 6,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/eke.txt": 3,
    # ... add more entries as needed
}
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps2 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/zke.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/zke.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/zke.txt": 26,
    "/DISK-0/gokul/ENGY/data/titli_3_e/zke.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/zke.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/zke.txt": 16,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/zke.txt": 2,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/zke.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/zke.txt": 16,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/zke.txt": 6,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/zke.txt": 3,
    # ... add more entries as needed
}
file_starting_timesteps3 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/zape.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/zape.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/zape.txt": 26,
    "/DISK-0/gokul/ENGY/data/titli_3_e/zape.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/zape.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/zape.txt": 16,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/zape.txt": 2,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/zape.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/zape.txt": 16,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/zape.txt": 6,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/zape.txt": 3,
    # ... add more entries as needed
}
file_starting_timesteps4 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/eape.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/eape.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/eape.txt": 26,
    "/DISK-0/gokul/ENGY/data/titli_3_e/eape.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/eape.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/eape.txt": 16,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/eape.txt": 2,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/eape.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/eape.txt": 16,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/eape.txt": 6,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/eape.txt": 3,
    # ... add more entries as needed
}
# Initialize an empty list to store data from each file
data_list1 = []
data_list2 = []
data_list3 = []
data_list4 = []

# Number of timesteps to extract from each file
num_timesteps_to_extract = 15

# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps1.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list1.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array1 = np.array(data_list1)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step1 = np.mean(data_array1, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step1)

# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps2.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list2.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array2 = np.array(data_list2)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step2 = np.mean(data_array2, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step2)
# Define the dictionary with file names and corresponding starting timesteps



# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps3.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list3.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array3 = np.array(data_list3)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step3 = np.mean(data_array3, axis=0)
# Print or use the mean_at_each_step as needed
print(mean_at_each_step3)

# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps4.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list4.append(data)

# Convert the list of lists into a NumPy array for easy manipulation
data_array4 = np.array(data_list4)

# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step4 = np.mean(data_array4, axis=0)

# Print or use the mean_at_each_step as needed
print(mean_at_each_step4)

# Generate timesteps (assuming your data starts from timestep 0)
timesteps = 3*np.arange(1,16)
# Plot the mean values
plt.figure(figsize=(8, 6))

# Plot the mean values with appropriate line styles, colors, and markers
plt.plot(timesteps, mean_at_each_step1, label='EKE', linewidth=2, linestyle='-', color='red', marker='o', markersize=7)
plt.plot(timesteps, mean_at_each_step2, label='ZKE', linewidth=2, linestyle='-', color='green', marker='s', markersize=7)
plt.plot(timesteps, mean_at_each_step3, label='ZAPE', linewidth=2, linestyle='-', color='blue', marker='^', markersize=7)
plt.plot(timesteps, mean_at_each_step4, label='EAPE', linewidth=2, linestyle='-', color='black', marker='D', markersize=7)


# Add labels and title with appropriate font sizes
plt.xlabel('Relative Time (Hours)', fontsize=19)
plt.ylabel('Energy (J/m²)', fontsize=19)
plt.title('RI TCs(Eulerian)', fontsize=21)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
# Add legend with appropriate font size
plt.legend(fontsize=12)
# Set y-axis in scientific notation with an exponent of 10^3
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
# Access the y-axis tick labels
y_formatter = plt.gca().get_yaxis().get_major_formatter()
plt.rc('font', size=17)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)
#plt.xticks(np.arange(1, 21) )


# Set a tight layout for better spacing
plt.tight_layout()
# Calculate the standard error of the mean along axis 0 (columns)
std_error_at_each_step1 = np.std(data_array1, axis=0) / np.sqrt(data_array1.shape[0])
std_error_at_each_step2 = np.std(data_array2, axis=0) / np.sqrt(data_array2.shape[0])
std_error_at_each_step3 = np.std(data_array3, axis=0) / np.sqrt(data_array3.shape[0])
std_error_at_each_step4 = np.std(data_array4, axis=0) / np.sqrt(data_array4.shape[0])


# Plot the mean values with error bars representing the standard error
# Plot the mean values with error bars representing the standard error for each energy term
#plt.errorbar(timesteps, mean_at_each_step1, yerr=std_error_at_each_step1, label='EKE', linewidth=1, linestyle='-', color='red', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step2, yerr=std_error_at_each_step2, label='ZKE', linewidth=1, linestyle='-', color='green', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step3, yerr=std_error_at_each_step3, label='ZAPE', linewidth=1, linestyle='-', color='blue', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step4, yerr=std_error_at_each_step4, label='EAPE', linewidth=1, linestyle='-', color='black', marker='None',capsize=4)
# Shade the region between the upper and lower bounds of standard error
plt.fill_between(timesteps, mean_at_each_step1 - std_error_at_each_step1, mean_at_each_step1 + std_error_at_each_step1, color='red', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step2 - std_error_at_each_step2, mean_at_each_step2 + std_error_at_each_step2, color='green', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step3 - std_error_at_each_step3, mean_at_each_step3 + std_error_at_each_step3, color='blue', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step4 - std_error_at_each_step4, mean_at_each_step4 + std_error_at_each_step4, color='black', alpha=0.3)

# Save the plot as a high-quality image for inclusion in the research paper
#plt.savefig('research_plot.png', dpi=300)

# Set x-axis ticks at alternative timesteps
plt.xticks(timesteps[::2])
plt.ylim(0,6e5)
plt.savefig('ri_composite_engy_eulerian.png', dpi=300)
# Show the plot
plt.show()
#Assuming you have already calculated mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4
# Define the directory path
directory = 'Composite_values'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
# Define filenames to save the mean values
file_names = ['Composite_values/RI_EKE_E.txt', 'Composite_values/RI_ZKE_E.txt', 'Composite_values/RI_ZAPE_E.txt', 'Composite_values/RI_EAPE_E.txt']

# Save mean values to separate files
for i, mean_at_each_step in enumerate([mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4]):
    np.savetxt(file_names[i], mean_at_each_step)
# Out:
# [166317.79271523 175755.36863934 185219.18390888 197828.21481262
#  205103.9224987  215844.19568601 225988.80130894 236191.72465538
#  245367.28949963 255674.57536513 262953.76129644 272412.9828096
#  277136.73719779 280496.28195994 282896.88745368]
# [470351.56538321 473674.30986354 477367.38952419 480710.05230591
#  482658.00516    490915.61115158 503361.41489166 508766.45121701
#  512848.13866557 511230.38789955 506398.81343944 497540.68252707
#  493390.62898191 495361.80621847 497336.40021405]
# [92633.38283895 90215.71247948 90698.05836559 89508.66315944
#  88464.40168822 89734.33490184 90622.96908405 91549.32787124
#  90415.56799389 87943.44438274 87472.42578953 89284.42105407
#  88893.15321086 88109.24913084 88925.27680921]
# [46366.45316116 51409.90341034 55780.49087888 53403.50099614
#  51341.64311002 49073.63405709 49541.77422353 51605.35964119
#  55953.36309704 59847.44388834 63667.85500015 61735.36255684
#  58840.20722797 55450.23353567 55455.00186359]
