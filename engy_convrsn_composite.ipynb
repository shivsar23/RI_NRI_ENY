# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps1 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/eape2eke.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/eape2eke.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/eape2eke.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/eape2eke.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/eape2eke.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/eape2eke.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/eape2eke.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/eape2eke.txt": 8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/eape2eke.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/aila_3_q/eape2eke.txt": 0,
    # ... add more entries as needed
}
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps2 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/cksum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/cksum.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/cksum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/cksum.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/cksum.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/cksum.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/cksum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/cksum.txt": 8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/cksum.txt":4,
    "/DISK-0/gokul/ENGY/dat2/aila_3_q/cksum.txt": 0,
    # ... add more entries as needed
}
file_starting_timesteps3 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/diss.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/diss.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/diss.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/diss.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/diss.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/diss.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/diss.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/diss.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/diss.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/diss.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/diss.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/diss.txt":8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/diss.txt": 4,
     "/DISK-0/gokul/ENGY/dat2/aila_3_q/diss.txt": 0,
    # ... add more entries as needed
}
file_starting_timesteps4 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/kebsum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/kebsum.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/kebsum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/kebsum.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/kebsum.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/kebsum.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/kebsum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/kebsum.txt": 8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/kebsum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/aila_3_q/kebsum.txt": 0,
    # ... add more entries as needed
}
file_starting_timesteps5 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_q/epebsum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_q/epebsum.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_q/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_q/epebsum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_q/epebsum.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_q/epebsum.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_q/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_q/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_q/epebsum.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_q/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_q/epebsum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_q/epebsum.txt": 8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_q/epebsum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/aila_3_q/epebsum.txt": 0,
    # ... add more entries as needed
}

# Initialize an empty list to store data from each file
data_list1 = []
data_list2 = []
data_list3 = []
data_list4 = []
data_list5 = []

# Number of timesteps to extract from each file
num_timesteps_to_extract = 15
#################################################################################################################################
# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps1.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            # Append data to the list
            data_list1.append(data)
############################################################################################################
for file_name, starting_timestep in file_starting_timesteps2.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list2.append(data)
##############################################################################################################
for file_name, starting_timestep in file_starting_timesteps3.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list3.append(data)
########################################################################################################
for file_name, starting_timestep in file_starting_timesteps4.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list4.append(data)
################################################################################################################################
# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps5.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list5.append(data)


# Convert the lists into NumPy arrays
data_array1 = np.array(data_list1)
data_array2 = np.array(data_list2)
data_array3 = np.array(data_list3)
data_array4 = np.array(data_list4)
data_array5 = np.array(data_list5)
# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step1 = np.mean(data_array1, axis=0)
mean_at_each_step2 = np.mean(data_array2, axis=0)  # Negate the mean for the second set of data
mean_at_each_step3 = -np.mean(data_array3, axis=0)
mean_at_each_step4 = np.mean(data_array4, axis=0)
mean_at_each_step5 = np.mean(data_array5, axis=0)

# Generate timesteps (assuming your data starts from timestep 0)
timesteps = 3*np.arange(1,16)

# Plot the mean values
plt.figure(figsize=(8, 6))

# Plot the mean values with appropriate line styles, colors, and markers
plt.plot(timesteps, mean_at_each_step1, label='CPK', linewidth=2, linestyle='-', color='red', marker='o', markersize=8)
plt.plot(timesteps, mean_at_each_step2, label='CK', linewidth=2, linestyle='-', color='green', marker='s', markersize=8)
plt.plot(timesteps, mean_at_each_step3, label='DE', linewidth=2, linestyle='-', color='blue', marker='^', markersize=8)
plt.plot(timesteps, mean_at_each_step4, label='KEB', linewidth=2, linestyle='-', color='black', marker='D', markersize=8)
plt.plot(timesteps, mean_at_each_step5, label='ΦEB', linewidth=2, linestyle='-', color='indigo', marker='*', markersize=8)

# Add labels and title with appropriate font sizes
plt.xlabel('Relative Time (Hours)', fontsize=19)
plt.ylabel('Conversion rate (W/m²)', fontsize=19)
plt.title('Non-RI TCs(quasi-Lagrangian)', fontsize=21)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)

# Add legend with appropriate font size
plt.legend(fontsize=12)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)
#plt.xticks(np.arange(1, 21) )


# Set a tight layout for better spacing
plt.tight_layout()
# Calculate the standard error of the mean along axis 0 (columns)
std_error_at_each_step1 = np.std(data_array1, axis=0) / np.sqrt(data_array1.shape[0])
std_error_at_each_step2 = np.std(data_array2, axis=0) / np.sqrt(data_array2.shape[0])
std_error_at_each_step3 = np.std(data_array3, axis=0) / np.sqrt(data_array3.shape[0])
std_error_at_each_step4 = np.std(data_array4, axis=0) / np.sqrt(data_array4.shape[0])
std_error_at_each_step5 = np.std(data_array5, axis=0) / np.sqrt(data_array5.shape[0])


# Plot the mean values with error bars representing the standard error
# Plot the mean values with error bars representing the standard error for each energy term
#plt.errorbar(timesteps, mean_at_each_step1, yerr=std_error_at_each_step1, linewidth=1, linestyle='-', color='red', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step2, yerr=std_error_at_each_step2, linewidth=1, linestyle='-', color='green', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step3, yerr=std_error_at_each_step3, linewidth=1, linestyle='-', color='blue', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step4, yerr=std_error_at_each_step4, linewidth=1, linestyle='-', color='black', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step5, yerr=std_error_at_each_step5,  linewidth=1, linestyle='-', color='grey', marker='None',capsize=4)
# Shade the region between the upper and lower bounds of standard error
plt.fill_between(timesteps, mean_at_each_step1 - std_error_at_each_step1, mean_at_each_step1 + std_error_at_each_step1, color='red', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step2 - std_error_at_each_step2, mean_at_each_step2 + std_error_at_each_step2, color='green', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step3 - std_error_at_each_step3, mean_at_each_step3 + std_error_at_each_step3, color='blue', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step4 - std_error_at_each_step4, mean_at_each_step4 + std_error_at_each_step4, color='black', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step5 - std_error_at_each_step5, mean_at_each_step5 + std_error_at_each_step5, color='indigo', alpha=0.3)


# Save the plot as a high-quality image for inclusion in the research paper
#plt.savefig('research_plot.png', dpi=300)

plt.xticks(timesteps[::2])
plt.ylim(-7,7)
plt.savefig('nri_composite_convrsnterms.png', dpi=300)
# Show the plot
plt.show()
#Assuming you have already calculated mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4
# Define the directory path
directory = 'Composite_values'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
# Define filenames to save the mean values
file_names = ['Composite_values/NRI_CPK.txt', 'Composite_values/NRI_CK.txt', 'Composite_values/NRI_DE.txt',
              'Composite_values/NRI_KEB.txt', 'Composite_values/NRI_ΦEB.txt']

# Save mean values to separate files
for i, mean_at_each_step in enumerate([mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4,mean_at_each_step5]):
    np.savetxt(file_names[i], mean_at_each_step)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps1 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/eape2eke.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/eape2eke.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_q/eape2eke.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/eape2eke.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/eape2eke.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/eape2eke.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/eape2eke.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/eape2eke.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/eape2eke.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/eape2eke.txt": 2,
    # ... add more entries as needed
}
file_starting_timesteps2 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/cksum.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/cksum.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_q/cksum.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/cksum.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/cksum.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/cksum.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/cksum.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/cksum.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/cksum.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/cksum.txt": 2,
    # ... add more entries as needed
}
file_starting_timesteps3 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/diss.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/diss.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/diss.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/diss.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_q/diss.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/diss.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/diss.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/diss.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/diss.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/diss.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/diss.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/diss.txt": 2,
    # ... add more entries as needed
}
file_starting_timesteps4 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/kebsum.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/kebsum.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_q/kebsum.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/kebsum.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/kebsum.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/kebsum.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/kebsum.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/kebsum.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/kebsum.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/kebsum.txt": 2,
    # ... add more entries as needed
}
file_starting_timesteps5 = {
    "/DISK-0/gokul/ENGY/data/giri_3_q/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_q/epebsum.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_q/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_q/epebsum.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_q/epebsum.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_q/epebsum.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_q/epebsum.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_q/epebsum.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_q/epebsum.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_q/epebsum.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_q/epebsum.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_q/epebsum.txt": 2,
    # ... add more entries as needed
}
# Initialize an empty list to store data from each file
data_list1 = []
data_list2 = []
data_list3 = []
data_list4 = []
data_list5 = []

# Number of timesteps to extract from each file
num_timesteps_to_extract = 15
#################################################################################################################################
# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps1.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            # Append data to the list
            data_list1.append(data)
############################################################################################################
for file_name, starting_timestep in file_starting_timesteps2.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list2.append(data)
##############################################################################################################
for file_name, starting_timestep in file_starting_timesteps3.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list3.append(data)
########################################################################################################
for file_name, starting_timestep in file_starting_timesteps4.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list4.append(data)
################################################################################################################################
# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps5.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list5.append(data)


# Convert the lists into NumPy arrays
data_array1 = np.array(data_list1)
data_array2 = np.array(data_list2)
data_array3 = np.array(data_list3)
data_array4 = np.array(data_list4)
data_array5 = np.array(data_list5)
# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step1 = np.mean(data_array1, axis=0)
mean_at_each_step2 = np.mean(data_array2, axis=0)  # Negate the mean for the second set of data
mean_at_each_step3 = -np.mean(data_array3, axis=0)
mean_at_each_step4 = np.mean(data_array4, axis=0)
mean_at_each_step5 = np.mean(data_array5, axis=0)

# Generate timesteps (assuming your data starts from timestep 0)
# Generate timesteps starting from 1
timesteps = 3*np.arange(1, 16)

# Plot the mean values
plt.figure(figsize=(8, 6))

# Plot the mean values with appropriate line styles, colors, and markers
plt.plot(timesteps, mean_at_each_step1, label='CPK', linewidth=2, linestyle='-', color='red', marker='o', markersize=8)
plt.plot(timesteps, mean_at_each_step2, label='CK', linewidth=2, linestyle='-', color='green', marker='s', markersize=8)
plt.plot(timesteps, mean_at_each_step3, label='DE', linewidth=2, linestyle='-', color='blue', marker='^', markersize=8)
plt.plot(timesteps, mean_at_each_step4, label='KEB', linewidth=2, linestyle='-', color='black', marker='D', markersize=8)
plt.plot(timesteps, mean_at_each_step5, label='ΦEB', linewidth=2, linestyle='-', color='indigo', marker='*', markersize=8)

# Add labels and title with appropriate font sizes
plt.xlabel('Relative Time (Hours)', fontsize=19)
plt.ylabel('Conversion rate (W/m²)', fontsize=19)
plt.title('RI TCs(quasi-Lagrangian)', fontsize=21)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)

# Add legend with appropriate font size
plt.legend(fontsize=12)


# Add grid lines on the x-axis at every 5 timesteps
plt.grid(True, linestyle='--', alpha=0.7)

# Set a tight layout for better spacing
plt.tight_layout()
# Calculate the standard error of the mean along axis 0 (columns)
std_error_at_each_step1 = np.std(data_array1, axis=0) / np.sqrt(data_array1.shape[0])
std_error_at_each_step2 = np.std(data_array2, axis=0) / np.sqrt(data_array2.shape[0])
std_error_at_each_step3 = np.std(data_array3, axis=0) / np.sqrt(data_array3.shape[0])
std_error_at_each_step4 = np.std(data_array4, axis=0) / np.sqrt(data_array4.shape[0])
std_error_at_each_step5 = np.std(data_array5, axis=0) / np.sqrt(data_array5.shape[0])


# Plot the mean values with error bars representing the standard error
# Plot the mean values with error bars representing the standard error for each energy term
#plt.errorbar(timesteps, mean_at_each_step1, yerr=std_error_at_each_step1, linewidth=1, linestyle='-', color='red', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step2, yerr=std_error_at_each_step2, linewidth=1, linestyle='-', color='green', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step3, yerr=std_error_at_each_step3, linewidth=1, linestyle='-', color='blue', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step4, yerr=std_error_at_each_step4, linewidth=1, linestyle='-', color='black', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step5, yerr=std_error_at_each_step5,  linewidth=1, linestyle='-', color='grey', marker='None',capsize=4)
plt.fill_between(timesteps, mean_at_each_step1 - std_error_at_each_step1, mean_at_each_step1 + std_error_at_each_step1, color='red', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step2 - std_error_at_each_step2, mean_at_each_step2 + std_error_at_each_step2, color='green', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step3 - std_error_at_each_step3, mean_at_each_step3 + std_error_at_each_step3, color='blue', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step4 - std_error_at_each_step4, mean_at_each_step4 + std_error_at_each_step4, color='black', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step5 - std_error_at_each_step5, mean_at_each_step5 + std_error_at_each_step5, color='indigo', alpha=0.3)
# Save the plot as a high-quality image for inclusion in the research paper
#plt.savefig('research_plot.png', dpi=300)
plt.xticks(timesteps[::2])
#plt.xticks(np.arange(1, 21) )
plt.ylim(-7,7)
plt.savefig('ri_composite_convrsnterms.png', dpi=300)
# Show the plot
plt.show()
#Assuming you have already calculated mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4
# Define the directory path
directory = 'Composite_values'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
# Define filenames to save the mean values
file_names = ['Composite_values/RI_CPK.txt', 'Composite_values/RI_CK.txt', 'Composite_values/RI_DE.txt',
              'Composite_values/RI_KEB.txt', 'Composite_values/RI_ΦEB.txt']

# Save mean values to separate files
for i, mean_at_each_step in enumerate([mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4,mean_at_each_step5]):
    np.savetxt(file_names[i], mean_at_each_step)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps1 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/eape2eke.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/eape2eke.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/eape2eke.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/eape2eke.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/eape2eke.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/eape2eke.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/eape2eke.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/eape2eke.txt": 8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/eape2eke.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/aila_3_e/eape2eke.txt": 0,
    # ... add more entries as needed
}
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps2 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/cksum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/cksum.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/cksum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/cksum.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/cksum.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/cksum.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/cksum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/cksum.txt": 8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/cksum.txt":4,
    "/DISK-0/gokul/ENGY/dat2/aila_3_e/cksum.txt": 0,
    # ... add more entries as needed
}
file_starting_timesteps3 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/diss.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/diss.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/diss.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/diss.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/diss.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/diss.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/diss.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/diss.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/diss.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/diss.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/diss.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/diss.txt":8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/diss.txt": 4,
     "/DISK-0/gokul/ENGY/dat2/aila_3_e/diss.txt": 0,
    # ... add more entries as needed
}
file_starting_timesteps4 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/kebsum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/kebsum.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/kebsum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/kebsum.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/kebsum.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/kebsum.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/kebsum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/kebsum.txt": 8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/kebsum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/aila_3_e/kebsum.txt": 0,
    # ... add more entries as needed
}
file_starting_timesteps5 = {
    "/DISK-0/gokul/ENGY/dat2/mandous_3_e/epebsum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/asani_3_e/epebsum.txt": 1,
    "/DISK-0/gokul/ENGY/dat2/yaas_3_e/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/nivar_3_e/epebsum.txt": 10,
    "/DISK-0/gokul/ENGY/dat2/phethai_3_e/epebsum.txt": 20,
    "/DISK-0/gokul/ENGY/dat2/gaja_3_e/epebsum.txt": 15,
    "/DISK-0/gokul/ENGY/dat2/mora_3_e/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/vardah_3_e/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/lehar_3_e/epebsum.txt": 5,
    "/DISK-0/gokul/ENGY/dat2/helen_3_e/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/dat2/thane_3_e/epebsum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/jal_3_e/epebsum.txt": 8,
    "/DISK-0/gokul/ENGY/dat2/laila_3_e/epebsum.txt": 4,
    "/DISK-0/gokul/ENGY/dat2/aila_3_e/epebsum.txt": 0,
    # ... add more entries as needed
}

# Initialize an empty list to store data from each file
data_list1 = []
data_list2 = []
data_list3 = []
data_list4 = []
data_list5 = []

# Number of timesteps to extract from each file
num_timesteps_to_extract = 15
#################################################################################################################################
# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps1.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            # Append data to the list
            data_list1.append(data)
############################################################################################################
for file_name, starting_timestep in file_starting_timesteps2.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list2.append(data)
##############################################################################################################
for file_name, starting_timestep in file_starting_timesteps3.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list3.append(data)
########################################################################################################
for file_name, starting_timestep in file_starting_timesteps4.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list4.append(data)
################################################################################################################################
# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps5.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list5.append(data)


# Convert the lists into NumPy arrays
data_array1 = np.array(data_list1)
data_array2 = np.array(data_list2)
data_array3 = np.array(data_list3)
data_array4 = np.array(data_list4)
data_array5 = np.array(data_list5)
# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step1 = np.mean(data_array1, axis=0)
mean_at_each_step2 = np.mean(data_array2, axis=0)  # Negate the mean for the second set of data
mean_at_each_step3 = -np.mean(data_array3, axis=0)
mean_at_each_step4 = np.mean(data_array4, axis=0)
mean_at_each_step5 = np.mean(data_array5, axis=0)

# Generate timesteps (assuming your data starts from timestep 0)
timesteps = 3*np.arange(1,16)

# Plot the mean values
plt.figure(figsize=(8, 6))

# Plot the mean values with appropriate line styles, colors, and markers
plt.plot(timesteps, mean_at_each_step1, label='CPK', linewidth=2, linestyle='-', color='red', marker='o', markersize=7)
plt.plot(timesteps, mean_at_each_step2, label='CK', linewidth=2, linestyle='-', color='green', marker='s', markersize=7)
plt.plot(timesteps, mean_at_each_step3, label='DE', linewidth=2, linestyle='-', color='blue', marker='^', markersize=7)
plt.plot(timesteps, mean_at_each_step4, label='KEB', linewidth=2, linestyle='-', color='black', marker='D', markersize=7)
plt.plot(timesteps, mean_at_each_step5, label='ΦEB', linewidth=2, linestyle='-', color='indigo', marker='*', markersize=7)

# Add labels and title with appropriate font sizes
plt.xlabel('Relative Time (Hours)', fontsize=19)
plt.ylabel('Conversion rate (W/m²)', fontsize=19)
plt.title('Non-RI TCs(Eulerian)', fontsize=21)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)

# Add legend with appropriate font size
plt.legend(fontsize=12)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)
#plt.xticks(np.arange(1, 21) )


# Set a tight layout for better spacing
plt.tight_layout()
# Calculate the standard error of the mean along axis 0 (columns)
std_error_at_each_step1 = np.std(data_array1, axis=0) / np.sqrt(data_array1.shape[0])
std_error_at_each_step2 = np.std(data_array2, axis=0) / np.sqrt(data_array2.shape[0])
std_error_at_each_step3 = np.std(data_array3, axis=0) / np.sqrt(data_array3.shape[0])
std_error_at_each_step4 = np.std(data_array4, axis=0) / np.sqrt(data_array4.shape[0])
std_error_at_each_step5 = np.std(data_array5, axis=0) / np.sqrt(data_array5.shape[0])


# Plot the mean values with error bars representing the standard error
# Plot the mean values with error bars representing the standard error for each energy term
#plt.errorbar(timesteps, mean_at_each_step1, yerr=std_error_at_each_step1, linewidth=1, linestyle='-', color='red', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step2, yerr=std_error_at_each_step2, linewidth=1, linestyle='-', color='green', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step3, yerr=std_error_at_each_step3, linewidth=1, linestyle='-', color='blue', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step4, yerr=std_error_at_each_step4, linewidth=1, linestyle='-', color='black', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step5, yerr=std_error_at_each_step5,  linewidth=1, linestyle='-', color='grey', marker='None',capsize=4)
plt.fill_between(timesteps, mean_at_each_step1 - std_error_at_each_step1, mean_at_each_step1 + std_error_at_each_step1, color='red', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step2 - std_error_at_each_step2, mean_at_each_step2 + std_error_at_each_step2, color='green', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step3 - std_error_at_each_step3, mean_at_each_step3 + std_error_at_each_step3, color='blue', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step4 - std_error_at_each_step4, mean_at_each_step4 + std_error_at_each_step4, color='black', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step5 - std_error_at_each_step5, mean_at_each_step5 + std_error_at_each_step5, color='indigo', alpha=0.3)

# Save the plot as a high-quality image for inclusion in the research paper
#plt.savefig('research_plot.png', dpi=300)

plt.xticks(timesteps[::2])
plt.ylim(-7,7)
plt.savefig('nri_composite_convrsnterms_eulerian.png', dpi=300)
# Show the plot
plt.show()
#Assuming you have already calculated mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4
# Define the directory path
directory = 'Composite_values'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
# Define filenames to save the mean values
file_names = ['Composite_values/NRI_CPK_E.txt', 'Composite_values/NRI_CK_E.txt', 'Composite_values/NRI_DE_E.txt',
              'Composite_values/NRI_KEB_E.txt', 'Composite_values/NRI_ΦEB_E.txt']

# Save mean values to separate files
for i, mean_at_each_step in enumerate([mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4,mean_at_each_step5]):
    np.savetxt(file_names[i], mean_at_each_step)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# Define the dictionary with file names and corresponding starting timesteps
file_starting_timesteps1 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/eape2eke.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/eape2eke.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/eape2eke.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_e/eape2eke.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/eape2eke.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/eape2eke.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/eape2eke.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/eape2eke.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/eape2eke.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/eape2eke.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/eape2eke.txt": 2,
    # ... add more entries as needed
}
file_starting_timesteps2 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/cksum.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/cksum.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/cksum.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_e/cksum.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/cksum.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/cksum.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/cksum.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/cksum.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/cksum.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/cksum.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/cksum.txt": 2,
    # ... add more entries as needed
}
file_starting_timesteps3 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/diss.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/diss.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/diss.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/diss.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_e/diss.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/diss.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/diss.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/diss.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/diss.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/diss.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/diss.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/diss.txt": 2,
    # ... add more entries as needed
}
file_starting_timesteps4 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/kebsum.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/kebsum.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/kebsum.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_e/kebsum.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/kebsum.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/kebsum.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/kebsum.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/kebsum.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/kebsum.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/kebsum.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/kebsum.txt": 2,
    # ... add more entries as needed
}
file_starting_timesteps5 = {
    "/DISK-0/gokul/ENGY/data/giri_3_e/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/data/phailin_3_e/epebsum.txt": 9,
    "/DISK-0/gokul/ENGY/data/madi_3_e/epebsum.txt": 0,
    "/DISK-0/gokul/ENGY/data/hudhud_3_e/epebsum.txt": 33,
    "/DISK-0/gokul/ENGY/data/titli_3_e/epebsum.txt": 8,
    "/DISK-0/gokul/ENGY/data/fani_3_e/epebsum.txt": 23,
    "/DISK-0/gokul/ENGY/data/bulbul_3_e/epebsum.txt": 6,
    "/DISK-0/gokul/ENGY/data/amphan_3_e/epebsum.txt": 16,
    "/DISK-0/gokul/ENGY/data/mocha_3_e/epebsum.txt": 10,
    "/DISK-0/gokul/ENGY/data/mala_3_e/epebsum.txt": 17,
    "/DISK-0/gokul/ENGY/data/sidr_3_e/epebsum.txt": 1,
    "/DISK-0/gokul/ENGY/data/nargis_3_e/epebsum.txt": 2,
    # ... add more entries as needed
}
# Initialize an empty list to store data from each file
data_list1 = []
data_list2 = []
data_list3 = []
data_list4 = []
data_list5 = []

# Number of timesteps to extract from each file
num_timesteps_to_extract = 15
#################################################################################################################################
# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps1.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            # Append data to the list
            data_list1.append(data)
############################################################################################################
for file_name, starting_timestep in file_starting_timesteps2.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list2.append(data)
##############################################################################################################
for file_name, starting_timestep in file_starting_timesteps3.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list3.append(data)
########################################################################################################
for file_name, starting_timestep in file_starting_timesteps4.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list4.append(data)
################################################################################################################################
# Read 30 timesteps from each file starting from the specified timestep
for file_name, starting_timestep in file_starting_timesteps5.items():
    with open(file_name, 'r') as file:
        # Read all lines from the file
        lines = file.readlines()
        
        # Check if there are at least 30 timesteps in the file starting from the specified timestep
        if len(lines) >= starting_timestep + num_timesteps_to_extract:
            # Extract 30 timesteps starting from the specified timestep
            data = [float(line.strip()) for line in lines[starting_timestep:starting_timestep + num_timesteps_to_extract]]
            
            # Append data to the list
            data_list5.append(data)


# Convert the lists into NumPy arrays
data_array1 = np.array(data_list1)
data_array2 = np.array(data_list2)
data_array3 = np.array(data_list3)
data_array4 = np.array(data_list4)
data_array5 = np.array(data_list5)
# Calculate the mean along axis 0 (columns) to get the mean at each step (line)
mean_at_each_step1 = np.mean(data_array1, axis=0)
mean_at_each_step2 = np.mean(data_array2, axis=0)  # Negate the mean for the second set of data
mean_at_each_step3 = -np.mean(data_array3, axis=0)
mean_at_each_step4 = np.mean(data_array4, axis=0)
mean_at_each_step5 = np.mean(data_array5, axis=0)

# Generate timesteps (assuming your data starts from timestep 0)
# Generate timesteps starting from 1
timesteps = 3*np.arange(1, 16)

# Plot the mean values
plt.figure(figsize=(8, 6))

# Plot the mean values with appropriate line styles, colors, and markers
plt.plot(timesteps, mean_at_each_step1, label='CPK', linewidth=2, linestyle='-', color='red', marker='o', markersize=7)
plt.plot(timesteps, mean_at_each_step2, label='CK', linewidth=2, linestyle='-', color='green', marker='s', markersize=7)
plt.plot(timesteps, mean_at_each_step3, label='DE', linewidth=2, linestyle='-', color='blue', marker='^', markersize=7)
plt.plot(timesteps, mean_at_each_step4, label='KEB', linewidth=2, linestyle='-', color='black', marker='D', markersize=7)
plt.plot(timesteps, mean_at_each_step5, label='ΦEB', linewidth=2, linestyle='-', color='indigo', marker='*', markersize=7)

# Add labels and title with appropriate font sizes
plt.xlabel('Relative Time (Hours)', fontsize=19)
plt.ylabel('Conversion rate (W/m²)', fontsize=19)
plt.title('RI TCs(Eulerian)', fontsize=21)
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)

# Add legend with appropriate font size
plt.legend(fontsize=12)


# Add grid lines on the x-axis at every 5 timesteps
plt.grid(True, linestyle='--', alpha=0.7)

# Set a tight layout for better spacing
plt.tight_layout()
# Calculate the standard error of the mean along axis 0 (columns)
std_error_at_each_step1 = np.std(data_array1, axis=0) / np.sqrt(data_array1.shape[0])
std_error_at_each_step2 = np.std(data_array2, axis=0) / np.sqrt(data_array2.shape[0])
std_error_at_each_step3 = np.std(data_array3, axis=0) / np.sqrt(data_array3.shape[0])
std_error_at_each_step4 = np.std(data_array4, axis=0) / np.sqrt(data_array4.shape[0])
std_error_at_each_step5 = np.std(data_array5, axis=0) / np.sqrt(data_array5.shape[0])


# Plot the mean values with error bars representing the standard error
# Plot the mean values with error bars representing the standard error for each energy term
#plt.errorbar(timesteps, mean_at_each_step1, yerr=std_error_at_each_step1, linewidth=1, linestyle='-', color='red', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step2, yerr=std_error_at_each_step2, linewidth=1, linestyle='-', color='green', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step3, yerr=std_error_at_each_step3, linewidth=1, linestyle='-', color='blue', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step4, yerr=std_error_at_each_step4, linewidth=1, linestyle='-', color='black', marker='None',capsize=4)
#plt.errorbar(timesteps, mean_at_each_step5, yerr=std_error_at_each_step5,  linewidth=1, linestyle='-', color='grey', marker='None',capsize=4)
plt.fill_between(timesteps, mean_at_each_step1 - std_error_at_each_step1, mean_at_each_step1 + std_error_at_each_step1, color='red', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step2 - std_error_at_each_step2, mean_at_each_step2 + std_error_at_each_step2, color='green', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step3 - std_error_at_each_step3, mean_at_each_step3 + std_error_at_each_step3, color='blue', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step4 - std_error_at_each_step4, mean_at_each_step4 + std_error_at_each_step4, color='black', alpha=0.3)
plt.fill_between(timesteps, mean_at_each_step5 - std_error_at_each_step5, mean_at_each_step5 + std_error_at_each_step5, color='indigo', alpha=0.3)

# Save the plot as a high-quality image for inclusion in the research paper
#plt.savefig('research_plot.png', dpi=300)
plt.xticks(timesteps[::2])
#plt.xticks(np.arange(1, 21) )
plt.ylim(-7,7)
plt.savefig('ri_composite_convrsnterms_eulerian.png', dpi=300)
# Show the plot
plt.show()
#Assuming you have already calculated mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4
# Define the directory path
directory = 'Composite_values'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)
# Define filenames to save the mean values
file_names = ['Composite_values/RI_CPK_E.txt', 'Composite_values/RI_CK_E.txt', 'Composite_values/RI_DE_E.txt',
              'Composite_values/RI_KEB_E.txt', 'Composite_values/RI_ΦEB_E.txt']

# Save mean values to separate files
for i, mean_at_each_step in enumerate([mean_at_each_step1, mean_at_each_step2, mean_at_each_step3, mean_at_each_step4,mean_at_each_step5]):
    np.savetxt(file_names[i], mean_at_each_step)
